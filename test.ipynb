# %%
import sys

import pandas as pd
import numpy as np

from bertopic import BERTopic

import asyncio

from text_topic_extraction.concept_extractor.concept_extractor import Concept, PatientConcepts
from text_topic_extraction.text_topic_processor import TextTopicProcessor, AsyncTextTopicProcessor, BERTopicModeler, QuestionGenerator, AnswerGenerator
from text_topic_extraction.config import API_VERSION, AZURE_ENDPOINT, OPENAI_API_KEY, USE_AZURE

# %%
np.random.seed(0)

# %%
question_prompt = """
The following topics were found in clinical notes. Generate yes/no questions for the following medical topics:
{topics_text}
Return a JSON object with topic numbers as keys and questions as values. Example:
{
"1": "Does the note mention the patient having a history of diabetes?"
}
"""

answer_prompt = """
You will be given a clinical note. I will give you a series of questions. Your task is answer each question with a probability from 0 to 1. Summarize the response with a JSON that includes your answer to all of the questions. Questions:
{prompt_questions}

clinical note:
{sentence}

Example answer: {
    "0": 0,
    "1": 1,
    "2": 0.5
}
Answer all the questions and do not answer with anything else besides valid JSON. Do not add comments to the JSON.
"""

# %%
llm_extract_df = pd.read_csv("../llm-bart/exp_mimic/_output/long_notes/max_obs_-1/seed_0/gpt-4o-mini/concept_extractions.csv")

# %%
llm_extract_df.llm_output
# Out:
# 0       male, man, gentleman,age 82, elderly, senior,s...
# 1       81-year-old, elderly, senior,female, woman, ad...
# 2       75 years, elderly, senior,man, male,retired, u...
# 3       66 year old, elderly, senior,male, man, adult,...
# 4       female, woman, patient,elderly, senior, aged,m...
#                               ...
# 7038    tobacco use, smoking, nicotine use,15 pack yea...
# 7039    86 M, elderly, senior,prostate cancer, cancer,...
# 7040    86 M, elderly, senior,prostate cancer, cancer,...
# 7041    elderly, senior, advanced age,female, woman,fe...
# 7042    male, man, gender,68 years old, elderly, senio...
# Name: llm_output, Length: 7043, dtype: object

# %%
rand_idxs = np.random.choice(llm_extract_df.shape[0], llm_extract_df.shape[0], replace=False)
train_idxs = rand_idxs[:400]
test_idxs = rand_idxs[400:800]

# %%
patient_notes = {}
for patient_id in train_idxs:
    note_text = llm_extract_df.iloc[patient_id].sentence
    note_type = "H&P"
    patient_notes[str(patient_id)] = [{"note_text": note_text, "note_type": note_type}]

# %%
concept_id = 0
patient_concepts = {}
for patient_id in train_idxs:
    a = llm_extract_df.iloc[patient_id].llm_output.split(",")
    concept_list = [Concept(id=str(concept_id + concept_offset_id), descriptor=protoconcept.strip().lower()) for concept_offset_id, protoconcept in enumerate(a)]
    concept_id += len(concept_list)
    patient_concepts[str(patient_id)] = PatientConcepts(
        patient_id=str(patient_id),
        all_concepts=concept_list
    )
# Out:
# {'2200': PatientConcepts(patient_id='2200', all_concepts=[Concept(id='0', descriptor='nkda', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='1', descriptor='no known drug allergies', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='2', descriptor='social history', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='3', descriptor='lifestyle factors', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='4', descriptor='history', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='5', descriptor='medical history', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='6', descriptor='demographics', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='7', descriptor='population data', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='8', descriptor='health status', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='9', descriptor='well-being', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='10', descriptor='risk factors', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='11', descriptor='health risks', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='12', descriptor='behavior', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='13', descriptor='habits', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='14', descriptor='environment', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='15', descriptor='surroundings', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='16', descriptor='access to care', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='17', descriptor='healthcare availability', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='18', descriptor='support system', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='19', descriptor='social support', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='20', descriptor='socioeconomic status', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='21', descriptor='income level', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='22', descriptor='cultural background', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='23', descriptor='ethnic background', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='24', descriptor='nutrition', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25', descriptor='dietary habits', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='26', descriptor='exercise', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='27', descriptor='physical activity', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='28', descriptor='living conditions', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='29', descriptor='housing situation', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='30', descriptor='employment status', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='31', descriptor='job situation', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='32', descriptor='education level', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='33', descriptor='academic background', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='34', descriptor='marital status', synonyms=[], source='llm', patient_i ...
#  '4627': PatientConcepts(patient_id='4627', all_concepts=[Concept(id='60', descriptor='65 yo', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='61', descriptor='elderly', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='62', descriptor='senior', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='63', descriptor='male', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='64', descriptor='man', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='65', descriptor='hiv', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='66', descriptor='aids', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='67', descriptor='immunocompromised', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='68', descriptor='cd4 244', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='69', descriptor='low cd4', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='70', descriptor='immunosuppression', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='71', descriptor='viral load 99', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='72', descriptor='low viral load', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='73', descriptor='darunavir-rit-truvada', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='74', descriptor='antiretroviral therapy', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='75', descriptor='cad', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='76', descriptor='coronary artery disease', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='77', descriptor='heart disease', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='78', descriptor='htn', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='79', descriptor='hypertension', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='80', descriptor='high blood pressure', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='81', descriptor='hyperlipidemia', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='82', descriptor='high cholesterol', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='83', descriptor='diverticulitis', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='84', descriptor='bowel disease', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='85', descriptor='urethral stenosis', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='86', descriptor='urinary obstruction', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='87', descriptor='utis', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='88', descriptor='urinary tract infections', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='89', descriptor='fever', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='90', descriptor='elevated temperature', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='91', descriptor='cough', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='92', descriptor='respiratory symptoms', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='93', descriptor='productive cough', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='94', descriptor='sputum production', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='95' ...
#  '3225': PatientConcepts(patient_id='3225', all_concepts=[Concept(id='126', descriptor='44 yo f', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='127', descriptor='middle-aged female', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='128', descriptor='aneurysm', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='129', descriptor='acomm aneurysm', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='130', descriptor='7 x 4 mm', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='131', descriptor='size', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='132', descriptor='asymptomatic', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='133', descriptor='no symptoms', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='134', descriptor='pain', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='135', descriptor='discomfort', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='136', descriptor='swelling', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='137', descriptor='edema', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='138', descriptor='maxillary ct', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='139', descriptor='imaging study', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='140', descriptor='periorbital abscess', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='141', descriptor='facial swelling', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='142', descriptor='smoking', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='143', descriptor='tobacco use', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='144', descriptor='pack per day', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='145', descriptor='heavy smoker', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='146', descriptor='alcohol use', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='147', descriptor='drinking', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='148', descriptor='six-pack per week', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='149', descriptor='moderate drinker', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='150', descriptor='waitress', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='151', descriptor='service industry', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='152', descriptor='elective admission', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='153', descriptor='planned procedure', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='154', descriptor='coiling', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='155', descriptor='endovascular treatment', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='156', descriptor='absence of headaches', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='157', descriptor='no headaches', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='158', descriptor='no neurological deficits', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='159', descriptor='normal exam', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='160', descriptor='no nausea', synonyms=[], source='llm', patient_id='', note_id ...
#  '2828': PatientConcepts(patient_id='2828', all_concepts=[Concept(id='186', descriptor='elderly', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='187', descriptor='senior', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='188', descriptor='female', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='189', descriptor='woman', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='190', descriptor='motor vehicle collision', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='191', descriptor='car accident', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='192', descriptor='right sided', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='193', descriptor='right', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='194', descriptor='rib fractures', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='195', descriptor='rib injuries', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='196', descriptor='pneumothorax', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='197', descriptor='lung injury', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='198', descriptor='conservative treatment', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='199', descriptor='non-invasive care', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='200', descriptor='malleolar fracture', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='201', descriptor='ankle fracture', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='202', descriptor='abdominal pain', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='203', descriptor='stomach pain', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='204', descriptor='ct scan', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='205', descriptor='imaging study', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='206', descriptor='fluid', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='207', descriptor='effusion', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='208', descriptor='rehabilitation center', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='209', descriptor='rehab facility', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='210', descriptor='intermittent', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='211', descriptor='occasional', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='212', descriptor='bilious vomitus', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='213', descriptor='bile vomiting', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='214', descriptor='diaphragm injury', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='215', descriptor='diaphragm damage', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='216', descriptor='bowel obstruction', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='217', descriptor='intestinal blockage', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='218', descriptor='right chest', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='219', descriptor='right thorax', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='220', descriptor='admission', synonyms=[], source='llm', patient_id ...
#  '3768': PatientConcepts(patient_id='3768', all_concepts=[Concept(id='246', descriptor='60 y/o', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='247', descriptor='elderly', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='248', descriptor='senior', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='249', descriptor='male', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='250', descriptor='man', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='251', descriptor='cryptogenic cirrhosis', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='252', descriptor='liver disease', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='253', descriptor='gastric varices', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='254', descriptor='varices', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='255', descriptor='hematemesis', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='256', descriptor='vomiting blood', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='257', descriptor='hospitalization', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='258', descriptor='admission', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='259', descriptor='icu', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='260', descriptor='intensive care unit', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='261', descriptor='somnolent', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='262', descriptor='drowsy', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='263', descriptor='lethargic', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='264', descriptor='arousable', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='265', descriptor='responsive', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='266', descriptor='blood transfusion', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='267', descriptor='prbcs', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='268', descriptor='ffp', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='269', descriptor='fresh frozen plasma', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='270', descriptor='octreotide', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='271', descriptor='medication', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='272', descriptor='protonix', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='273', descriptor='proton pump inhibitor', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='274', descriptor='endoscopy', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='275', descriptor='egd', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='276', descriptor='encephalopathy', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='277', descriptor='altered mental status', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='278', descriptor='lactulose', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='279', descriptor='medication', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='280', descriptor='spouse', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='281', descriptor='wife', synonyms= ...
#  '4446': PatientConcepts(patient_id='4446', all_concepts=[Concept(id='308', descriptor='male', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='309', descriptor='man', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='310', descriptor='gender', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='311', descriptor='61 y/o', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='312', descriptor='age', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='313', descriptor='elderly', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='314', descriptor='daily alcohol use', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='315', descriptor='ethanol intake', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='316', descriptor='alcohol consumption', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='317', descriptor='nausea', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='318', descriptor='queasiness', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='319', descriptor='black tarry stools', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='320', descriptor='melena', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='321', descriptor='gastrointestinal bleeding', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='322', descriptor='no abdominal pain', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='323', descriptor='absence of pain', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='324', descriptor='lightheadedness', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='325', descriptor='dizziness', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='326', descriptor='no syncope', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='327', descriptor='consciousness intact', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='328', descriptor='hemoglobin', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='329', descriptor='hct', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='330', descriptor='hematocrit', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='331', descriptor='blood transfusion', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='332', descriptor='blood units', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='333', descriptor='iv ppi', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='334', descriptor='proton pump inhibitor', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='335', descriptor='egd', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='336', descriptor='upper endoscopy', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='337', descriptor='gastrointestinal scope', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='338', descriptor='stable', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='339', descriptor='hemodynamically stable', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='340', descriptor='smoker', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='341', descriptor='former smoker', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='342', descriptor='tobacco user', synonyms=[], source='llm', patient_id='', note_id='', metadata={}),  ...
#  '2234': PatientConcepts(patient_id='2234', all_concepts=[Concept(id='377', descriptor='48 y.o.', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='378', descriptor='middle-aged', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='379', descriptor='adult', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='380', descriptor='female', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='381', descriptor='woman', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='382', descriptor='girl', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='383', descriptor='type 1 diabetes', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='384', descriptor='dm type 1', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='385', descriptor='insulin-dependent diabetes', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='386', descriptor='hcv', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='387', descriptor='hepatitis c', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='388', descriptor='viral hepatitis', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='389', descriptor='esrd', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='390', descriptor='end-stage renal disease', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='391', descriptor='kidney failure', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='392', descriptor='hd', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='393', descriptor='hemodialysis', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='394', descriptor='dialysis', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='395', descriptor='weakness', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='396', descriptor='fatigue', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='397', descriptor='malaise', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='398', descriptor='hickman catheter', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='399', descriptor='central line', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='400', descriptor='venous access', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='401', descriptor='blood cultures', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='402', descriptor='blood tests', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='403', descriptor='microbiologic cultures', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='404', descriptor='positive culture', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='405', descriptor='cultured organism', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='406', descriptor='infection', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='407', descriptor='enterococcus', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='408', descriptor='bacteria', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='409', descriptor='pathogen', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='410', descriptor='pan-sensitive', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='411', descriptor='susceptible', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='412', descr ...
#  '5454': PatientConcepts(patient_id='5454', all_concepts=[Concept(id='467', descriptor='80 years old', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='468', descriptor='elderly', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='469', descriptor='senior', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='470', descriptor='hispanic', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='471', descriptor='latino', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='472', descriptor='female', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='473', descriptor='woman', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='474', descriptor='known heart disease', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='475', descriptor='cardiac condition', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='476', descriptor='heart issues', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='477', descriptor='chest pressure', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='478', descriptor='chest pain', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='479', descriptor='angina', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='480', descriptor='gurgling sensation', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='481', descriptor='throat discomfort', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='482', descriptor='cared for', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='483', descriptor='supported', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='484', descriptor='relies on family', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='485', descriptor='diaphoretic', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='486', descriptor='sweating', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='487', descriptor='perspiring', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='488', descriptor='labile blood pressure', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='489', descriptor='unstable bp', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='490', descriptor='fluctuating blood pressure', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='491', descriptor='emergency treatment', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='492', descriptor='urgent care', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='493', descriptor='acute assistance', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='494', descriptor='nitroglycerin', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='495', descriptor='vasodilator', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='496', descriptor='heart medication', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='497', descriptor='lasix', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='498', descriptor='diuretic', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='499', descriptor='fluid medication', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='500', descriptor='morphine', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='501', descriptor='pain relief', synonyms=[], source='llm', patient_id='', note_id='', met ...
#  '1278': PatientConcepts(patient_id='1278', all_concepts=[Concept(id='522', descriptor='42 year-old', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='523', descriptor='middle-aged', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='524', descriptor='adult', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='525', descriptor='female', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='526', descriptor='woman', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='527', descriptor='lady', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='528', descriptor='schizophrenia', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='529', descriptor='mental illness', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='530', descriptor='psychiatric disorder', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='531', descriptor='mental retardation', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='532', descriptor='intellectual disability', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='533', descriptor='developmental delay', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='534', descriptor='increased lethargy', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='535', descriptor='fatigue', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='536', descriptor='tiredness', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='537', descriptor='decreased po intake', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='538', descriptor='poor appetite', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='539', descriptor='reduced food intake', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='540', descriptor='low grade fever', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='541', descriptor='slight fever', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='542', descriptor='mild temperature', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='543', descriptor='breathing rapidly', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='544', descriptor='tachypnea', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='545', descriptor='quick respiration', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='546', descriptor='no abdominal pain', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='547', descriptor='absence of pain', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='548', descriptor='no discomfort', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='549', descriptor='no nausea', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='550', descriptor='absence of nausea', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='551', descriptor='no queasiness', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='552', descriptor='no vomiting', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='553', descriptor='absence of vomiting', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='554', descriptor='no emesis', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='555', descriptor='no diarrhea', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='556', descriptor='absence of diarrhea', sy ...
#  '578': PatientConcepts(patient_id='578', all_concepts=[Concept(id='612', descriptor='51 year old', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='613', descriptor='middle-aged', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='614', descriptor='adult', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='615', descriptor='male', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='616', descriptor='man', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='617', descriptor='boy', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='618', descriptor='diabetes', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='619', descriptor='insulin dependent', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='620', descriptor='dm', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='621', descriptor='end stage renal disease', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='622', descriptor='esrd', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='623', descriptor='kidney failure', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='624', descriptor='renal transplant', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='625', descriptor='kidney transplant', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='626', descriptor='transplantation', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='627', descriptor='fever', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='628', descriptor='elevated temperature', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='629', descriptor='pyrexia', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='630', descriptor='chills', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='631', descriptor='shivering', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='632', descriptor='cold sensations', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='633', descriptor='watery diarrhea', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='634', descriptor='diarrhea', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='635', descriptor='loose stools', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='636', descriptor='malaise', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='637', descriptor='fatigue', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='638', descriptor='tiredness', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='639', descriptor='mental status change', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='640', descriptor='delirium', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='641', descriptor='confusion', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='642', descriptor='antibiotic treatment', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='643', descriptor='antimicrobial therapy', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='644', descriptor='antibiotics', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='645', descriptor='no nausea', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='646', descriptor='absence of nausea', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='647', des ...
#  '5960': PatientConcepts(patient_id='5960', all_concepts=[Concept(id='672', descriptor='female', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='673', descriptor='woman', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='674', descriptor='83 years old', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='675', descriptor='elderly', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='676', descriptor='senior', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='677', descriptor="alzheimer's dementia", synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='678', descriptor='dementia', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='679', descriptor='cognitive impairment', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='680', descriptor='atria fibrillation', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='681', descriptor='arrhythmia', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='682', descriptor='heart condition', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='683', descriptor='rvr', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='684', descriptor='rapid ventricular response', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='685', descriptor='tachycardia', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='686', descriptor='diastolic dysfunction', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='687', descriptor='heart failure', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='688', descriptor='cardiac issue', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='689', descriptor='cad', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='690', descriptor='coronary artery disease', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='691', descriptor='heart disease', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='692', descriptor='hypertrophic cardiomyopathy', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='693', descriptor='heart condition', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='694', descriptor='cardiac hypertrophy', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='695', descriptor='peripheral vascular disease', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='696', descriptor='pvd', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='697', descriptor='vascular issue', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='698', descriptor='breast cancer', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='699', descriptor='oncology', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='700', descriptor='malignancy history', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='701', descriptor='lumpectomy', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='702', descriptor='breast surgery', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='703', descriptor='surgical intervention', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='704', descriptor='rehab', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='705', descriptor='rehabilitation', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='706', descriptor='recovery', synony ...
# ...
#  '6608': PatientConcepts(patient_id='6608', all_concepts=[Concept(id='25508', descriptor='79 year old', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25509', descriptor='elderly', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25510', descriptor='senior', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25511', descriptor='male', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25512', descriptor='man', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25513', descriptor='masculine', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25514', descriptor='adenocarcinoma', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25515', descriptor='colon cancer', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25516', descriptor='cancer', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25517', descriptor='s/p chemotherapy', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25518', descriptor='after chemo', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25519', descriptor='post-chemotherapy', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25520', descriptor='5-fu', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25521', descriptor='fluorouracil', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25522', descriptor='chemotherapy drug', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25523', descriptor='dark chocolate pudding stools', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25524', descriptor='melena', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25525', descriptor='bloody stools', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25526', descriptor='lightheadedness', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25527', descriptor='dizziness', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25528', descriptor='vertigo', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25529', descriptor='generalized weakness', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25530', descriptor='fatigue', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25531', descriptor='lethargy', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25532', descriptor='hematocrit 19.0', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25533', descriptor='low hematocrit', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25534', descriptor='anemia', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25535', descriptor='tachycardia', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25536', descriptor='rapid heart rate', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25537', descriptor='fast heartbeat', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25538', descriptor='hypotension', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25539', descriptor='low blood pressure', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25540', descriptor='low bp', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25541', descriptor='prbcs', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25542', descriptor='packed red blood cells', syno ...
#  '2655': PatientConcepts(patient_id='2655', all_concepts=[Concept(id='25598', descriptor='61 years old', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25599', descriptor='elderly', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25600', descriptor='senior', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25601', descriptor='unknown pmh', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25602', descriptor='unknown medical history', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25603', descriptor='unclear medical history', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25604', descriptor='bike accident', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25605', descriptor='cycling accident', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25606', descriptor='bicycle injury', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25607', descriptor='intubated', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25608', descriptor='ventilated', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25609', descriptor='airway secured', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25610', descriptor='confused', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25611', descriptor='disoriented', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25612', descriptor='agitated', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25613', descriptor='facial fractures', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25614', descriptor='maxillofacial fractures', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25615', descriptor='facial injuries', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25616', descriptor='skull fractures', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25617', descriptor='cranial fractures', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25618', descriptor='left frontal fracture', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25619', descriptor='frontal skull fracture', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25620', descriptor='intracranial hemorrhage', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25621', descriptor='iph', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25622', descriptor='brain bleed', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25623', descriptor='subarachnoid hemorrhage', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25624', descriptor='sah', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25625', descriptor='brain bleed', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25626', descriptor='spinal fractures', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25627', descriptor='vertebral fractures', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25628', descriptor='triple antibiotics', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25629', descriptor='broad-spectrum antibiotics', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25630', descriptor='pepcid', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25631', descriptor='famotidine', synonyms=[], source='llm' ...
#  '3597': PatientConcepts(patient_id='3597', all_concepts=[Concept(id='25683', descriptor='57-year-old', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25684', descriptor='middle-aged', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25685', descriptor='demographic', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25686', descriptor='woman', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25687', descriptor='female', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25688', descriptor='gender', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25689', descriptor='hypertension', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25690', descriptor='htn', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25691', descriptor='high blood pressure', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25692', descriptor='hyperlipidemia', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25693', descriptor='high cholesterol', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25694', descriptor='lipid disorder', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25695', descriptor='alcoholic cirrhosis', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25696', descriptor='liver disease', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25697', descriptor='liver cirrhosis', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25698', descriptor='renal dysfunction', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25699', descriptor='kidney failure', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25700', descriptor='acute renal failure', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25701', descriptor='arf', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25702', descriptor='worsening function', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25703', descriptor='deteriorating condition', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25704', descriptor='progression', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25705', descriptor='ascites', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25706', descriptor='fluid retention', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25707', descriptor='abdominal fluid', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25708', descriptor='abnormal liver function tests', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25709', descriptor='lfts', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25710', descriptor='liver enzymes', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25711', descriptor='increased ammonia', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25712', descriptor='elevated ammonia', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25713', descriptor='hyperammonemia', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25714', descriptor='hospital transfer', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25715', descriptor='inter-facility transfer', synonyms=[], source='llm', patient_id='', note_id='', metadata={}), Concept(id='25716', descriptor='admission', synonyms=[], source='llm', patient_id='', note_id ...

# %%
processor = TextTopicProcessor(
    model_type="gpt-4o-mini-2024-07-18", #"gpt-4o-2024-08-06",
    temperature=0.0,
    num_topics=None,
    use_cache=True,
    use_structured_output=True,
    use_azure=False,
    azure_endpoint=AZURE_ENDPOINT,
    api_version=API_VERSION,
    api_key=OPENAI_API_KEY,
    cache_dir="cache",
    concept_prompt_template="{notes}",
    concept_questions_prompt_template=question_prompt,
    answer_prompt_template=answer_prompt
)
# Out:
# 2025-03-13 07:47:41,575 - text_topic_extraction.cache.cache_manager - INFO - Text Topic Extraction cache initialized at cache/text_topic_cache.duckdb
# 2025-03-13 07:47:41,585 - text_topic_extraction.text_topic_processor - INFO - Initialized TextTopicProcessor with model gpt-4o-mini-2024-07-18

# %%
processor.patient_notes = patient_notes

# %%
processor.openai_client.client

# %%
topic_modeler = BERTopicModeler(
    num_topics=processor.num_topics,
    embedding_model=(
        processor.embedding_model if processor.embedding_model != "default" else None
    ),
    vectorizer_model=processor.vectorizer_model,
    min_topic_size=processor.min_topic_size,
    language=processor.language,
    n_gram_range=processor.n_gram_range,
)

question_generator = QuestionGenerator(
    llm_api=processor.openai_client,
    batch_prompt_template=processor.concept_questions_prompt_template,
)
answer_generator = AnswerGenerator(
    llm_api=processor.openai_client, prompt_template=processor.answer_prompt_template
)
# Out:
# 2025-03-13 07:47:54,119 - text_topic_extraction.topic_modeler.bertopic_modeler - INFO - Initialized BERTopicModeler with None topics

# %%
topics = processor._perform_topic_modeling(
    patient_concepts=patient_concepts,
    topic_modeler=topic_modeler,
)
# Out:
# 2025-03-13 06:15:30,364 - text_topic_extraction.text_topic_processor - INFO - Performing topic modeling on concepts from 400 patients
# 2025-03-13 06:15:30,393 - sentence_transformers.SentenceTransformer - INFO - Use pytorch device_name: mps
# 2025-03-13 06:15:30,393 - sentence_transformers.SentenceTransformer - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-03-13 06:16:03,251 - text_topic_extraction.text_topic_processor - INFO - Generated 1319 topics
# 2025-03-13 06:16:03,252 - text_topic_extraction.text_topic_processor - INFO - Topic 0: elderly aging person
# 2025-03-13 06:16:03,252 - text_topic_extraction.text_topic_processor - INFO - Topic 1: male cyclist individual
# 2025-03-13 06:16:03,252 - text_topic_extraction.text_topic_processor - INFO - Topic 2: social history unknown
# 2025-03-13 06:16:03,252 - text_topic_extraction.text_topic_processor - INFO - Topic 3: senior gentleman man
# 2025-03-13 06:16:03,253 - text_topic_extraction.text_topic_processor - INFO - Topic 4: man lad
# 2025-03-13 06:16:03,253 - text_topic_extraction.text_topic_processor - INFO - Topic 5: female girl 75y
# 2025-03-13 06:16:03,253 - text_topic_extraction.text_topic_processor - INFO - Topic 6: woman lady she
# 2025-03-13 06:16:03,253 - text_topic_extraction.text_topic_processor - INFO - Topic 7: factors lifestyle
# 2025-03-13 06:16:03,253 - text_topic_extraction.text_topic_processor - INFO - Topic 8: middleaged middleclass advanced
# 2025-03-13 06:16:03,253 - text_topic_extraction.text_topic_processor - INFO - Topic 9: hypertension hypertensive antihypertensive
# 2025-03-13 06:16:03,254 - text_topic_extraction.text_topic_processor - INFO - Topic 10: dyspnea tachypnea polydipsia
# 2025-03-13 06:16:03,254 - text_topic_extraction.text_topic_processor - INFO - Topic 11: spouse estranged second
# 2025-03-13 06:16:03,254 - text_topic_extraction.text_topic_processor - INFO - Topic 12: tumor cancer neoplasm
# 2025-03-13 06:16:03,254 - text_topic_extraction.text_topic_processor - INFO - Topic 13: medical history complex
# 2025-03-13 06:16:03,254 - text_topic_extraction.text_topic_processor - INFO - Topic 14: shortness breath of
# 2025-03-13 06:16:03,254 - text_topic_extraction.text_topic_processor - INFO - Topic 15: coronary artery disease
# 2025-03-13 06:16:03,255 - text_topic_extraction.text_topic_processor - INFO - Topic 16: treatment regimen options
# 2025-03-13 06:16:03,255 - text_topic_extraction.text_topic_processor - INFO - Topic 17: adult mature admit
# 2025-03-13 06:16:03,255 - text_topic_extraction.text_topic_processor - INFO - Topic 18: surgery planned thrombectomy
# 2025-03-13 06:16:03,255 - text_topic_extraction.text_topic_processor - INFO - Topic 19: hypotension hypotensive postural
# 2025-03-13 06:16:03,255 - text_topic_extraction.text_topic_processor - INFO - Topic 20: high pressure blood
# 2025-03-13 06:16:03,255 - text_topic_extraction.text_topic_processor - INFO - Topic 21: antibiotic cement macrolide
# 2025-03-13 06:16:03,256 - text_topic_extraction.text_topic_processor - INFO - Topic 22: nausea sickness nauseous
# 2025-03-13 06:16:03,256 - text_topic_extraction.text_topic_processor - INFO - Topic 23: cad noncad drawings
# 2025-03-13 06:16:03,256 - text_topic_extraction.text_topic_processor - INFO - Topic 24: fatigue exhaustion intolerance
# 2025-03-13 06:16:03,256 - text_topic_extraction.text_topic_processor - INFO - Topic 25: tobacco cigarette use
# 2025-03-13 06:16:03,256 - text_topic_extraction.text_topic_processor - INFO - Topic 26: hospitalization hospitalizations hospitalisation
# 2025-03-13 06:16:03,256 - text_topic_extraction.text_topic_processor - INFO - Topic 27: abdominal belly abd
# 2025-03-13 06:16:03,256 - text_topic_extraction.text_topic_processor - INFO - Topic 28: vomiting throwing up
# 2025-03-13 06:16:03,257 - text_topic_extraction.text_topic_processor - INFO - Topic 29: fever feverish fevers
# 2025-03-13 06:16:03,257 - text_topic_extraction.text_topic_processor - INFO - Topic 30: yo 61 47yo
# 2025-03-13 06:16:03,257 - text_topic_extraction.text_topic_processor - INFO - Topic 31: low pressure blood
# 2025-03-13 06:16:03,257 - text_topic_extraction.text_topic_processor - INFO - Topic 32: smoking pipe smoked
# 2025-03-13 06:16:03,257 - text_topic_extraction.text_topic_processor - INFO - Topic 33: disease cardiovascular heart
# 2025-03-13 06:16:03,257 - text_topic_extraction.text_topic_processor - INFO - Topic 34: married marriage wedlock
# 2025-03-13 06:16:03,257 - text_topic_extraction.text_topic_processor - INFO - Topic 35: stable stability loadbearing
# 2025-03-13 06:16:03,258 - text_topic_extraction.text_topic_processor - INFO - Topic 36: chest twinges transient
# 2025-03-13 06:16:03,258 - text_topic_extraction.text_topic_processor - INFO - Topic 37: vital signs observations
# 2025-03-13 06:16:03,258 - text_topic_extraction.text_topic_processor - INFO - Topic 38: situation living life
# 2025-03-13 06:16:03,258 - text_topic_extraction.text_topic_processor - INFO - Topic 39: relatives family large
# 2025-03-13 06:16:03,258 - text_topic_extraction.text_topic_processor - INFO - Topic 40: quit smoking recently
# 2025-03-13 06:16:03,259 - text_topic_extraction.text_topic_processor - INFO - Topic 41: headache bifrontal dull
# 2025-03-13 06:16:03,259 - text_topic_extraction.text_topic_processor - INFO - Topic 42: alcohol does drink
# 2025-03-13 06:16:03,259 - text_topic_extraction.text_topic_processor - INFO - Topic 43: diabetes diabetic supplies
# 2025-03-13 06:16:03,259 - text_topic_extraction.text_topic_processor - INFO - Topic 44: historian documented provide
# 2025-03-13 06:16:03,259 - text_topic_extraction.text_topic_processor - INFO - Topic 45: weakness frailty progressive
# 2025-03-13 06:16:03,259 - text_topic_extraction.text_topic_processor - INFO - Topic 46: discomfort uncomfortable spasticity
# 2025-03-13 06:16:03,260 - text_topic_extraction.text_topic_processor - INFO - Topic 47: interhospital transfer hospital
# 2025-03-13 06:16:03,260 - text_topic_extraction.text_topic_processor - INFO - Topic 48: alcohol use misuse
# 2025-03-13 06:16:03,260 - text_topic_extraction.text_topic_processor - INFO - Topic 49: emesis coffee ground
# 2025-03-13 06:16:03,260 - text_topic_extraction.text_topic_processor - INFO - Topic 50: support family parents
# 2025-03-13 06:16:03,260 - text_topic_extraction.text_topic_processor - INFO - Topic 51: evaluation evaluations two
# 2025-03-13 06:16:03,260 - text_topic_extraction.text_topic_processor - INFO - Topic 52: infection meningitis bacterial
# 2025-03-13 06:16:03,260 - text_topic_extraction.text_topic_processor - INFO - Topic 53: fibrillation atrial paroxysmal
# 2025-03-13 06:16:03,261 - text_topic_extraction.text_topic_processor - INFO - Topic 54: stroke strokes cane
# 2025-03-13 06:16:03,261 - text_topic_extraction.text_topic_processor - INFO - Topic 55: trauma traumatic ptsd
# 2025-03-13 06:16:03,261 - text_topic_extraction.text_topic_processor - INFO - Topic 56: invasive procedure minimally
# 2025-03-13 06:16:03,261 - text_topic_extraction.text_topic_processor - INFO - Topic 57: department emergency evaluation
# 2025-03-13 06:16:03,261 - text_topic_extraction.text_topic_processor - INFO - Topic 58: pneumonia aspiration eosinophilic
# 2025-03-13 06:16:03,261 - text_topic_extraction.text_topic_processor - INFO - Topic 59: exercise physically activity
# 2025-03-13 06:16:03,262 - text_topic_extraction.text_topic_processor - INFO - Topic 60: medication medications reactions
# 2025-03-13 06:16:03,262 - text_topic_extraction.text_topic_processor - INFO - Topic 61: tobacco does smoke
# 2025-03-13 06:16:03,262 - text_topic_extraction.text_topic_processor - INFO - Topic 62: offspring emergent descendants
# 2025-03-13 06:16:03,263 - text_topic_extraction.text_topic_processor - INFO - Topic 63: lifestyle nonrevitalization choice
# 2025-03-13 06:16:03,263 - text_topic_extraction.text_topic_processor - INFO - Topic 64: swelling pulsatile ble
# 2025-03-13 06:16:03,263 - text_topic_extraction.text_topic_processor - INFO - Topic 65: imaging radiographic venipuncture
# 2025-03-13 06:16:03,263 - text_topic_extraction.text_topic_processor - INFO - Topic 66: angina pectoris darunavirrittruvada
# 2025-03-13 06:16:03,263 - text_topic_extraction.text_topic_processor - INFO - Topic 67: intensive unit care
# 2025-03-13 06:16:03,264 - text_topic_extraction.text_topic_processor - INFO - Topic 68: productive cough no
# 2025-03-13 06:16:03,264 - text_topic_extraction.text_topic_processor - INFO - Topic 69: edema le ankle
# 2025-03-13 06:16:03,264 - text_topic_extraction.text_topic_processor - INFO - Topic 70: queasiness queasy sequelae
# 2025-03-13 06:16:03,264 - text_topic_extraction.text_topic_processor - INFO - Topic 71: chf dchf csf
# 2025-03-13 06:16:03,264 - text_topic_extraction.text_topic_processor - INFO - Topic 72: education college academic
# 2025-03-13 06:16:03,264 - text_topic_extraction.text_topic_processor - INFO - Topic 73: scan ct scans
# 2025-03-13 06:16:03,265 - text_topic_extraction.text_topic_processor - INFO - Topic 74: admission elective reason
# 2025-03-13 06:16:03,265 - text_topic_extraction.text_topic_processor - INFO - Topic 75: icu nkda ic
# 2025-03-13 06:16:03,265 - text_topic_extraction.text_topic_processor - INFO - Topic 76: urgent preventive immediate
# 2025-03-13 06:16:03,265 - text_topic_extraction.text_topic_processor - INFO - Topic 77: former smoker firefighter
# 2025-03-13 06:16:03,265 - text_topic_extraction.text_topic_processor - INFO - Topic 78: past medical complex
# 2025-03-13 06:16:03,265 - text_topic_extraction.text_topic_processor - INFO - Topic 79: yo over 84
# 2025-03-13 06:16:03,266 - text_topic_extraction.text_topic_processor - INFO - Topic 80: diarrhea watery absence
# 2025-03-13 06:16:03,266 - text_topic_extraction.text_topic_processor - INFO - Topic 81: recovery remission phase
# 2025-03-13 06:16:03,266 - text_topic_extraction.text_topic_processor - INFO - Topic 82: gender identity orientation
# 2025-03-13 06:16:03,266 - text_topic_extraction.text_topic_processor - INFO - Topic 83: fluids iv solumedrol
# 2025-03-13 06:16:03,266 - text_topic_extraction.text_topic_processor - INFO - Topic 84: anxiety photophobia unease
# 2025-03-13 06:16:03,267 - text_topic_extraction.text_topic_processor - INFO - Topic 85: saturation o2 paleness
# 2025-03-13 06:16:03,267 - text_topic_extraction.text_topic_processor - INFO - Topic 86: etoh intertroch incoherent
# 2025-03-13 06:16:03,267 - text_topic_extraction.text_topic_processor - INFO - Topic 87: admitted eligible iii
# 2025-03-13 06:16:03,267 - text_topic_extraction.text_topic_processor - INFO - Topic 88: seizure seizures epilepsy
# 2025-03-13 06:16:03,267 - text_topic_extraction.text_topic_processor - INFO - Topic 89: kidney failure renal
# 2025-03-13 06:16:03,268 - text_topic_extraction.text_topic_processor - INFO - Topic 90: acute episode need
# 2025-03-13 06:16:03,268 - text_topic_extraction.text_topic_processor - INFO - Topic 91: strategy manager administrative
# 2025-03-13 06:16:03,268 - text_topic_extraction.text_topic_processor - INFO - Topic 92: tachycardia tachycardic supraventricular
# 2025-03-13 06:16:03,268 - text_topic_extraction.text_topic_processor - INFO - Topic 93: intubated reintubated intubate
# 2025-03-13 06:16:03,268 - text_topic_extraction.text_topic_processor - INFO - Topic 94: sounds lung pulmonary
# 2025-03-13 06:16:03,268 - text_topic_extraction.text_topic_processor - INFO - Topic 95: assessment initial tool
# 2025-03-13 06:16:03,268 - text_topic_extraction.text_topic_processor - INFO - Topic 96: temperature elevated co2
# 2025-03-13 06:16:03,269 - text_topic_extraction.text_topic_processor - INFO - Topic 97: surgery implant cardiogenic
# 2025-03-13 06:16:03,269 - text_topic_extraction.text_topic_processor - INFO - Topic 98: abstinent from drugs
# 2025-03-13 06:16:03,269 - text_topic_extraction.text_topic_processor - INFO - Topic 99: drinking weekend thirst
# 2025-03-13 06:16:03,269 - text_topic_extraction.text_topic_processor - INFO - Topic 100: retired semiretired
# 2025-03-13 06:16:03,269 - text_topic_extraction.text_topic_processor - INFO - Topic 101: support welfare social
# 2025-03-13 06:16:03,269 - text_topic_extraction.text_topic_processor - INFO - Topic 102: neurological neuro sclerosis
# 2025-03-13 06:16:03,269 - text_topic_extraction.text_topic_processor - INFO - Topic 103: afebrile embolus auricle
# 2025-03-13 06:16:03,270 - text_topic_extraction.text_topic_processor - INFO - Topic 104: kids children locations
# 2025-03-13 06:16:03,270 - text_topic_extraction.text_topic_processor - INFO - Topic 105: patient patients update
# 2025-03-13 06:16:03,270 - text_topic_extraction.text_topic_processor - INFO - Topic 106: catheterization catheter cardiac
# 2025-03-13 06:16:03,270 - text_topic_extraction.text_topic_processor - INFO - Topic 107: healthcare insurance uninsured
# 2025-03-13 06:16:03,270 - text_topic_extraction.text_topic_processor - INFO - Topic 108: admission hospital entry
# 2025-03-13 06:16:03,271 - text_topic_extraction.text_topic_processor - INFO - Topic 109: substance misuse emerging
# 2025-03-13 06:16:03,271 - text_topic_extraction.text_topic_processor - INFO - Topic 110: dental checkup mouth
# 2025-03-13 06:16:03,271 - text_topic_extraction.text_topic_processor - INFO - Topic 111: evaluation judgment eval
# 2025-03-13 06:16:03,271 - text_topic_extraction.text_topic_processor - INFO - Topic 112: asymptomatic management
# 2025-03-13 06:16:03,271 - text_topic_extraction.text_topic_processor - INFO - Topic 113: smoking unclear history
# 2025-03-13 06:16:03,271 - text_topic_extraction.text_topic_processor - INFO - Topic 114: hemorrhage hemorrhagic hemorrhoids
# 2025-03-13 06:16:03,272 - text_topic_extraction.text_topic_processor - INFO - Topic 115: confusion confused rule
# 2025-03-13 06:16:03,272 - text_topic_extraction.text_topic_processor - INFO - Topic 116: antibiotics broadspectrum clostridium
# 2025-03-13 06:16:03,272 - text_topic_extraction.text_topic_processor - INFO - Topic 117: socioeconomic determinants contributing
# 2025-03-13 06:16:03,272 - text_topic_extraction.text_topic_processor - INFO - Topic 118: symptoms flulike somatic
# 2025-03-13 06:16:03,272 - text_topic_extraction.text_topic_processor - INFO - Topic 119: crying buttock tender
# 2025-03-13 06:16:03,272 - text_topic_extraction.text_topic_processor - INFO - Topic 120: pressure 12671 unmanaged
# 2025-03-13 06:16:03,272 - text_topic_extraction.text_topic_processor - INFO - Topic 121: occasional rarely drinks
# 2025-03-13 06:16:03,273 - text_topic_extraction.text_topic_processor - INFO - Topic 122: stomach ache soreness
# 2025-03-13 06:16:03,273 - text_topic_extraction.text_topic_processor - INFO - Topic 123: cardiomyopathy ventricular ventricle
# 2025-03-13 06:16:03,273 - text_topic_extraction.text_topic_processor - INFO - Topic 124: partner romantic ill
# 2025-03-13 06:16:03,273 - text_topic_extraction.text_topic_processor - INFO - Topic 125: preexisting better improved
# 2025-03-13 06:16:03,273 - text_topic_extraction.text_topic_processor - INFO - Topic 126: lung infection pharyngitis
# 2025-03-13 06:16:03,274 - text_topic_extraction.text_topic_processor - INFO - Topic 127: chronic conditions condition
# 2025-03-13 06:16:03,274 - text_topic_extraction.text_topic_processor - INFO - Topic 128: tobaccofree free tobacco
# 2025-03-13 06:16:03,274 - text_topic_extraction.text_topic_processor - INFO - Topic 129: drug contraceptives deficits
# 2025-03-13 06:16:03,274 - text_topic_extraction.text_topic_processor - INFO - Topic 130: critical vigilant care
# 2025-03-13 06:16:03,274 - text_topic_extraction.text_topic_processor - INFO - Topic 131: vodka spirits liquor
# 2025-03-13 06:16:03,274 - text_topic_extraction.text_topic_processor - INFO - Topic 132: dizziness dizzy nondizzy
# 2025-03-13 06:16:03,275 - text_topic_extraction.text_topic_processor - INFO - Topic 133: htn conn suspected
# 2025-03-13 06:16:03,275 - text_topic_extraction.text_topic_processor - INFO - Topic 134: ratio normalized examination
# 2025-03-13 06:16:03,275 - text_topic_extraction.text_topic_processor - INFO - Topic 135: hospitalized released from
# 2025-03-13 06:16:03,275 - text_topic_extraction.text_topic_processor - INFO - Topic 136: hemiparesis hematemesis hemoptysis
# 2025-03-13 06:16:03,275 - text_topic_extraction.text_topic_processor - INFO - Topic 137: intake po poor
# 2025-03-13 06:16:03,276 - text_topic_extraction.text_topic_processor - INFO - Topic 138: residence resides residing
# 2025-03-13 06:16:03,276 - text_topic_extraction.text_topic_processor - INFO - Topic 139: 51 50yearold 44yearold
# 2025-03-13 06:16:03,276 - text_topic_extraction.text_topic_processor - INFO - Topic 140: nondrinker nonalcoholic exdrinker
# 2025-03-13 06:16:03,276 - text_topic_extraction.text_topic_processor - INFO - Topic 141: young adult person
# 2025-03-13 06:16:03,276 - text_topic_extraction.text_topic_processor - INFO - Topic 142: rare drinking drinker
# 2025-03-13 06:16:03,276 - text_topic_extraction.text_topic_processor - INFO - Topic 143: loose stools stool
# 2025-03-13 06:16:03,277 - text_topic_extraction.text_topic_processor - INFO - Topic 144: sdoh sdh sscp
# 2025-03-13 06:16:03,277 - text_topic_extraction.text_topic_processor - INFO - Topic 145: facility institution correctional
# 2025-03-13 06:16:03,277 - text_topic_extraction.text_topic_processor - INFO - Topic 146: heparin warfarin lepirudin
# 2025-03-13 06:16:03,277 - text_topic_extraction.text_topic_processor - INFO - Topic 147: catheter catheterization quinton
# 2025-03-13 06:16:03,277 - text_topic_extraction.text_topic_processor - INFO - Topic 148: provider healthcare providers
# 2025-03-13 06:16:03,278 - text_topic_extraction.text_topic_processor - INFO - Topic 149: caregiver informal babysitter
# 2025-03-13 06:16:03,278 - text_topic_extraction.text_topic_processor - INFO - Topic 150: arrhythmia tachyarrhythmia arrhythmias
# 2025-03-13 06:16:03,278 - text_topic_extraction.text_topic_processor - INFO - Topic 151: working longer nonworking
# 2025-03-13 06:16:03,278 - text_topic_extraction.text_topic_processor - INFO - Topic 152: assessment check bedside
# 2025-03-13 06:16:03,278 - text_topic_extraction.text_topic_processor - INFO - Topic 153: demographic demographics population
# 2025-03-13 06:16:03,278 - text_topic_extraction.text_topic_processor - INFO - Topic 154: liver steatohepatitis fatty
# 2025-03-13 06:16:03,279 - text_topic_extraction.text_topic_processor - INFO - Topic 155: tiredness tired excessive
# 2025-03-13 06:16:03,279 - text_topic_extraction.text_topic_processor - INFO - Topic 156: wound wounds stab
# 2025-03-13 06:16:03,279 - text_topic_extraction.text_topic_processor - INFO - Topic 157: cigarettes smokes charcoal
# 2025-03-13 06:16:03,279 - text_topic_extraction.text_topic_processor - INFO - Topic 158: congestive failure biventricular
# 2025-03-13 06:16:03,280 - text_topic_extraction.text_topic_processor - INFO - Topic 159: airway management lumen
# 2025-03-13 06:16:03,280 - text_topic_extraction.text_topic_processor - INFO - Topic 160: walking gait movement
# 2025-03-13 06:16:03,280 - text_topic_extraction.text_topic_processor - INFO - Topic 161: rehabilitation past
# 2025-03-13 06:16:03,280 - text_topic_extraction.text_topic_processor - INFO - Topic 162: stent stenting drugeluting
# 2025-03-13 06:16:03,281 - text_topic_extraction.text_topic_processor - INFO - Topic 163: ed
# 2025-03-13 06:16:03,281 - text_topic_extraction.text_topic_processor - INFO - Topic 164: transfer helicopter for
# 2025-03-13 06:16:03,281 - text_topic_extraction.text_topic_processor - INFO - Topic 165: sweating sweatiness sweaty
# 2025-03-13 06:16:03,281 - text_topic_extraction.text_topic_processor - INFO - Topic 166: relocation transferred tranquilization
# 2025-03-13 06:16:03,281 - text_topic_extraction.text_topic_processor - INFO - Topic 167: child infant baby
# 2025-03-13 06:16:03,281 - text_topic_extraction.text_topic_processor - INFO - Topic 168: alone lives live
# 2025-03-13 06:16:03,282 - text_topic_extraction.text_topic_processor - INFO - Topic 169: hypoxia hypoxic hypokinesis
# 2025-03-13 06:16:03,282 - text_topic_extraction.text_topic_processor - INFO - Topic 170: weight loss losing
# 2025-03-13 06:16:03,282 - text_topic_extraction.text_topic_processor - INFO - Topic 171: independent dependents dependency
# 2025-03-13 06:16:03,282 - text_topic_extraction.text_topic_processor - INFO - Topic 172: intubation intubations intubate
# 2025-03-13 06:16:03,282 - text_topic_extraction.text_topic_processor - INFO - Topic 173: unemployed unemployment pay
# 2025-03-13 06:16:03,282 - text_topic_extraction.text_topic_processor - INFO - Topic 174: troponin trach trop
# 2025-03-13 06:16:03,283 - text_topic_extraction.text_topic_processor - INFO - Topic 175: detox heroin substance
# 2025-03-13 06:16:03,283 - text_topic_extraction.text_topic_processor - INFO - Topic 176: urination bladder painful
# 2025-03-13 06:16:03,283 - text_topic_extraction.text_topic_processor - INFO - Topic 177: fall falls postfall
# 2025-03-13 06:16:03,283 - text_topic_extraction.text_topic_processor - INFO - Topic 178: procedure elective uncomplicated
# 2025-03-13 06:16:03,283 - text_topic_extraction.text_topic_processor - INFO - Topic 179: group home peer
# 2025-03-13 06:16:03,284 - text_topic_extraction.text_topic_processor - INFO - Topic 180: inpatient care
# 2025-03-13 06:16:03,284 - text_topic_extraction.text_topic_processor - INFO - Topic 181: risk factor factors
# 2025-03-13 06:16:03,284 - text_topic_extraction.text_topic_processor - INFO - Topic 182: background info established
# 2025-03-13 06:16:03,284 - text_topic_extraction.text_topic_processor - INFO - Topic 183: cabg postcabg bar
# 2025-03-13 06:16:03,284 - text_topic_extraction.text_topic_processor - INFO - Topic 184: lightheadedness lightheaded no
# 2025-03-13 06:16:03,285 - text_topic_extraction.text_topic_processor - INFO - Topic 185: bp 7030 8040
# 2025-03-13 06:16:03,285 - text_topic_extraction.text_topic_processor - INFO - Topic 186: oxygen deprivation levels
# 2025-03-13 06:16:03,285 - text_topic_extraction.text_topic_processor - INFO - Topic 187: smoker heavy current
# 2025-03-13 06:16:03,285 - text_topic_extraction.text_topic_processor - INFO - Topic 188: parttime employed employment
# 2025-03-13 06:16:03,285 - text_topic_extraction.text_topic_processor - INFO - Topic 189: pancreatitis pancreatic gallstone
# 2025-03-13 06:16:03,286 - text_topic_extraction.text_topic_processor - INFO - Topic 190: xray chest xrays
# 2025-03-13 06:16:03,286 - text_topic_extraction.text_topic_processor - INFO - Topic 191: duration period minutes
# 2025-03-13 06:16:03,286 - text_topic_extraction.text_topic_processor - INFO - Topic 192: smoking extensive history
# 2025-03-13 06:16:03,286 - text_topic_extraction.text_topic_processor - INFO - Topic 193: sob wnl no
# 2025-03-13 06:16:03,286 - text_topic_extraction.text_topic_processor - INFO - Topic 194: transportation transport transience
# 2025-03-13 06:16:03,287 - text_topic_extraction.text_topic_processor - INFO - Topic 195: breathlessness nighttime puffiness
# 2025-03-13 06:16:03,287 - text_topic_extraction.text_topic_processor - INFO - Topic 196: attack progressing strain
# 2025-03-13 06:16:03,287 - text_topic_extraction.text_topic_processor - INFO - Topic 197: lesion obtuse marginal
# 2025-03-13 06:16:03,287 - text_topic_extraction.text_topic_processor - INFO - Topic 198: respiratory inhaled compromise
# 2025-03-13 06:16:03,287 - text_topic_extraction.text_topic_processor - INFO - Topic 199: vision blindness eye
# 2025-03-13 06:16:03,287 - text_topic_extraction.text_topic_processor - INFO - Topic 200: blockage blocked blockages
# 2025-03-13 06:16:03,288 - text_topic_extraction.text_topic_processor - INFO - Topic 201: location door nc
# 2025-03-13 06:16:03,288 - text_topic_extraction.text_topic_processor - INFO - Topic 202: condition heart cardiac
# 2025-03-13 06:16:03,288 - text_topic_extraction.text_topic_processor - INFO - Topic 203: cxr shows prox
# 2025-03-13 06:16:03,288 - text_topic_extraction.text_topic_processor - INFO - Topic 204: age underage 16
# 2025-03-13 06:16:03,288 - text_topic_extraction.text_topic_processor - INFO - Topic 205: unresponsive hyperreflexia unresponsiveness
# 2025-03-13 06:16:03,288 - text_topic_extraction.text_topic_processor - INFO - Topic 206: copd flare stage
# 2025-03-13 06:16:03,288 - text_topic_extraction.text_topic_processor - INFO - Topic 207: attention intervention interventions
# 2025-03-13 06:16:03,289 - text_topic_extraction.text_topic_processor - INFO - Topic 208: cri cr uri
# 2025-03-13 06:16:03,289 - text_topic_extraction.text_topic_processor - INFO - Topic 209: ulcer ulcers peptic
# 2025-03-13 06:16:03,289 - text_topic_extraction.text_topic_processor - INFO - Topic 210: laboratory lab results
# 2025-03-13 06:16:03,289 - text_topic_extraction.text_topic_processor - INFO - Topic 211: hct hcp hepc
# 2025-03-13 06:16:03,289 - text_topic_extraction.text_topic_processor - INFO - Topic 212: aspirin somatostatin qd
# 2025-03-13 06:16:03,290 - text_topic_extraction.text_topic_processor - INFO - Topic 213: parent childless tree
# 2025-03-13 06:16:03,290 - text_topic_extraction.text_topic_processor - INFO - Topic 214: illicit illegal substances
# 2025-03-13 06:16:03,290 - text_topic_extraction.text_topic_processor - INFO - Topic 215: sobriety sober duration
# 2025-03-13 06:16:03,290 - text_topic_extraction.text_topic_processor - INFO - Topic 216: esophageal esophagitis esophagus
# 2025-03-13 06:16:03,290 - text_topic_extraction.text_topic_processor - INFO - Topic 217: control management pain
# 2025-03-13 06:16:03,290 - text_topic_extraction.text_topic_processor - INFO - Topic 218: transferred translation helicopter
# 2025-03-13 06:16:03,290 - text_topic_extraction.text_topic_processor - INFO - Topic 219: head ct correlate
# 2025-03-13 06:16:03,291 - text_topic_extraction.text_topic_processor - INFO - Topic 220: ems emt airlines
# 2025-03-13 06:16:03,291 - text_topic_extraction.text_topic_processor - INFO - Topic 221: longterm months shortterm
# 2025-03-13 06:16:03,291 - text_topic_extraction.text_topic_processor - INFO - Topic 222: moved relocated mv
# 2025-03-13 06:16:03,291 - text_topic_extraction.text_topic_processor - INFO - Topic 223: altered mental status
# 2025-03-13 06:16:03,291 - text_topic_extraction.text_topic_processor - INFO - Topic 224: chest pain no
# 2025-03-13 06:16:03,291 - text_topic_extraction.text_topic_processor - INFO - Topic 225: side sides both
# 2025-03-13 06:16:03,291 - text_topic_extraction.text_topic_processor - INFO - Topic 226: mental change retardation
# 2025-03-13 06:16:03,292 - text_topic_extraction.text_topic_processor - INFO - Topic 227: inflammation cellulitis antiinflammatory
# 2025-03-13 06:16:03,292 - text_topic_extraction.text_topic_processor - INFO - Topic 228: collection pink fluid
# 2025-03-13 06:16:03,292 - text_topic_extraction.text_topic_processor - INFO - Topic 229: dm dm2 d50
# 2025-03-13 06:16:03,292 - text_topic_extraction.text_topic_processor - INFO - Topic 230: mass solid nonthrobbing
# 2025-03-13 06:16:03,292 - text_topic_extraction.text_topic_processor - INFO - Topic 231: single
# 2025-03-13 06:16:03,293 - text_topic_extraction.text_topic_processor - INFO - Topic 232: respiratory support breathing
# 2025-03-13 06:16:03,293 - text_topic_extraction.text_topic_processor - INFO - Topic 233: drugfree petfree lifestyle
# 2025-03-13 06:16:03,293 - text_topic_extraction.text_topic_processor - INFO - Topic 234: neurology peptide natriuretic
# 2025-03-13 06:16:03,293 - text_topic_extraction.text_topic_processor - INFO - Topic 235: tracing longterm illness
# 2025-03-13 06:16:03,293 - text_topic_extraction.text_topic_processor - INFO - Topic 236: insulin drip nasal
# 2025-03-13 06:16:03,293 - text_topic_extraction.text_topic_processor - INFO - Topic 237: aorta dilated ascending
# 2025-03-13 06:16:03,294 - text_topic_extraction.text_topic_processor - INFO - Topic 238: abuse nonabuse substance
# 2025-03-13 06:16:03,294 - text_topic_extraction.text_topic_processor - INFO - Topic 239: cerebrovascular accident cerebrospinal
# 2025-03-13 06:16:03,294 - text_topic_extraction.text_topic_processor - INFO - Topic 240: drugs boxing using
# 2025-03-13 06:16:03,294 - text_topic_extraction.text_topic_processor - INFO - Topic 241: monitoring surveillance check
# 2025-03-13 06:16:03,294 - text_topic_extraction.text_topic_processor - INFO - Topic 242: bleeding parenchymal nonbleed
# 2025-03-13 06:16:03,294 - text_topic_extraction.text_topic_processor - INFO - Topic 243: mellitus diabetes ketoacidosis
# 2025-03-13 06:16:03,295 - text_topic_extraction.text_topic_processor - INFO - Topic 244: substances substance asbestos
# 2025-03-13 06:16:03,295 - text_topic_extraction.text_topic_processor - INFO - Topic 245: aneurysm aneurysms acomm
# 2025-03-13 06:16:03,295 - text_topic_extraction.text_topic_processor - INFO - Topic 246: graft grafts saphenous
# 2025-03-13 06:16:03,295 - text_topic_extraction.text_topic_processor - INFO - Topic 247: tract urinary infections
# 2025-03-13 06:16:03,296 - text_topic_extraction.text_topic_processor - INFO - Topic 248: tube peg endotracheal
# 2025-03-13 06:16:03,296 - text_topic_extraction.text_topic_processor - INFO - Topic 249: afib rvr with
# 2025-03-13 06:16:03,296 - text_topic_extraction.text_topic_processor - INFO - Topic 250: disability disabled intellectual
# 2025-03-13 06:16:03,296 - text_topic_extraction.text_topic_processor - INFO - Topic 251: gastric gastritis gastrointestinal
# 2025-03-13 06:16:03,297 - text_topic_extraction.text_topic_processor - INFO - Topic 252: nephrolithiasis kidney diabetesrelated
# 2025-03-13 06:16:03,297 - text_topic_extraction.text_topic_processor - INFO - Topic 253: limits within state
# 2025-03-13 06:16:03,297 - text_topic_extraction.text_topic_processor - INFO - Topic 254: echocardiogram echocardiograms transesophageal
# 2025-03-13 06:16:03,298 - text_topic_extraction.text_topic_processor - INFO - Topic 255: household chores tax
# 2025-03-13 06:16:03,298 - text_topic_extraction.text_topic_processor - INFO - Topic 256: with lives stayathome
# 2025-03-13 06:16:03,298 - text_topic_extraction.text_topic_processor - INFO - Topic 257: other relationship girlfriend
# 2025-03-13 06:16:03,298 - text_topic_extraction.text_topic_processor - INFO - Topic 258: daughter granddaughter grandchild
# 2025-03-13 06:16:03,299 - text_topic_extraction.text_topic_processor - INFO - Topic 259: lvef rca ef
# 2025-03-13 06:16:03,299 - text_topic_extraction.text_topic_processor - INFO - Topic 260: sister sibling siblings
# 2025-03-13 06:16:03,299 - text_topic_extraction.text_topic_processor - INFO - Topic 261: independent living independently
# 2025-03-13 06:16:03,299 - text_topic_extraction.text_topic_processor - INFO - Topic 262: urine output culture
# 2025-03-13 06:16:03,299 - text_topic_extraction.text_topic_processor - INFO - Topic 263: solitary solo supine
# 2025-03-13 06:16:03,300 - text_topic_extraction.text_topic_processor - INFO - Topic 264: psychosis schizoaffective delusions
# 2025-03-13 06:16:03,300 - text_topic_extraction.text_topic_processor - INFO - Topic 265: gentleman
# 2025-03-13 06:16:03,300 - text_topic_extraction.text_topic_processor - INFO - Topic 266: valve prosthetic anomaly
# 2025-03-13 06:16:03,300 - text_topic_extraction.text_topic_processor - INFO - Topic 267: hypercholesterolemia cholesterol high
# 2025-03-13 06:16:03,300 - text_topic_extraction.text_topic_processor - INFO - Topic 268: mechanical ventilation noninvasive
# 2025-03-13 06:16:03,300 - text_topic_extraction.text_topic_processor - INFO - Topic 269: perfusion mri imaging
# 2025-03-13 06:16:03,301 - text_topic_extraction.text_topic_processor - INFO - Topic 270: temperature cooling degrees
# 2025-03-13 06:16:03,301 - text_topic_extraction.text_topic_processor - INFO - Topic 271: fainting faintness fainted
# 2025-03-13 06:16:03,301 - text_topic_extraction.text_topic_processor - INFO - Topic 272: dialysis hemodialysis most
# 2025-03-13 06:16:03,301 - text_topic_extraction.text_topic_processor - INFO - Topic 273: travel traveler trip
# 2025-03-13 06:16:03,301 - text_topic_extraction.text_topic_processor - INFO - Topic 274: rehab session resident
# 2025-03-13 06:16:03,301 - text_topic_extraction.text_topic_processor - INFO - Topic 275: incarcerated jail probation
# 2025-03-13 06:16:03,302 - text_topic_extraction.text_topic_processor - INFO - Topic 276: nonreconstructable occlusive diseasefree
# 2025-03-13 06:16:03,302 - text_topic_extraction.text_topic_processor - INFO - Topic 277: failure respiratory hypercarbic
# 2025-03-13 06:16:03,302 - text_topic_extraction.text_topic_processor - INFO - Topic 278: injuries injury case
# 2025-03-13 06:16:03,302 - text_topic_extraction.text_topic_processor - INFO - Topic 279: bypass grafting graft
# 2025-03-13 06:16:03,302 - text_topic_extraction.text_topic_processor - INFO - Topic 280: pantoprazole pallor lorazepam
# 2025-03-13 06:16:03,302 - text_topic_extraction.text_topic_processor - INFO - Topic 281: resuscitation cardiopulmonary revived
# 2025-03-13 06:16:03,302 - text_topic_extraction.text_topic_processor - INFO - Topic 282: therapy psychotherapy counselor
# 2025-03-13 06:16:03,303 - text_topic_extraction.text_topic_processor - INFO - Topic 283: postoperative preoperative postsurgery
# 2025-03-13 06:16:03,303 - text_topic_extraction.text_topic_processor - INFO - Topic 284: mitral endocarditis prolapse
# 2025-03-13 06:16:03,303 - text_topic_extraction.text_topic_processor - INFO - Topic 285: facility external referring
# 2025-03-13 06:16:03,303 - text_topic_extraction.text_topic_processor - INFO - Topic 286: steroid steroids cream
# 2025-03-13 06:16:03,303 - text_topic_extraction.text_topic_processor - INFO - Topic 287: infarction myocardial negative
# 2025-03-13 06:16:03,303 - text_topic_extraction.text_topic_processor - INFO - Topic 288: patient oversight history
# 2025-03-13 06:16:03,304 - text_topic_extraction.text_topic_processor - INFO - Topic 289: abstainer
# 2025-03-13 06:16:03,304 - text_topic_extraction.text_topic_processor - INFO - Topic 290: intensive care surgical
# 2025-03-13 06:16:03,304 - text_topic_extraction.text_topic_processor - INFO - Topic 291: illicit drugs substances
# 2025-03-13 06:16:03,304 - text_topic_extraction.text_topic_processor - INFO - Topic 292: diuretic diuresis diuretics
# 2025-03-13 06:16:03,304 - text_topic_extraction.text_topic_processor - INFO - Topic 293: ppd ppi 1ppd
# 2025-03-13 06:16:03,305 - text_topic_extraction.text_topic_processor - INFO - Topic 294: asthma wheezing labored
# 2025-03-13 06:16:03,305 - text_topic_extraction.text_topic_processor - INFO - Topic 295: prehospital specialty nonhospital
# 2025-03-13 06:16:03,305 - text_topic_extraction.text_topic_processor - INFO - Topic 296: marital relationship status
# 2025-03-13 06:16:03,305 - text_topic_extraction.text_topic_processor - INFO - Topic 297: accident helmeted wearing
# 2025-03-13 06:16:03,305 - text_topic_extraction.text_topic_processor - INFO - Topic 298: vancomycin cytotec clindamycin
# 2025-03-13 06:16:03,305 - text_topic_extraction.text_topic_processor - INFO - Topic 299: diagnosis manifestations diagnoses
# 2025-03-13 06:16:03,306 - text_topic_extraction.text_topic_processor - INFO - Topic 300: son boy well
# 2025-03-13 06:16:03,306 - text_topic_extraction.text_topic_processor - INFO - Topic 301: ns nsclc aicd
# 2025-03-13 06:16:03,306 - text_topic_extraction.text_topic_processor - INFO - Topic 302: electrocardiogram electrophysiology imbalance
# 2025-03-13 06:16:03,306 - text_topic_extraction.text_topic_processor - INFO - Topic 303: anticoagulant
# 2025-03-13 06:16:03,306 - text_topic_extraction.text_topic_processor - INFO - Topic 304: obstructive pulmonary chronic
# 2025-03-13 06:16:03,306 - text_topic_extraction.text_topic_processor - INFO - Topic 305: chills
# 2025-03-13 06:16:03,307 - text_topic_extraction.text_topic_processor - INFO - Topic 306: referral site dry
# 2025-03-13 06:16:03,307 - text_topic_extraction.text_topic_processor - INFO - Topic 307: hemodynamically hemodynamic hemodynamics
# 2025-03-13 06:16:03,307 - text_topic_extraction.text_topic_processor - INFO - Topic 308: record records file
# 2025-03-13 06:16:03,307 - text_topic_extraction.text_topic_processor - INFO - Topic 309: hydration water warm
# 2025-03-13 06:16:03,307 - text_topic_extraction.text_topic_processor - INFO - Topic 310: back midback backache
# 2025-03-13 06:16:03,308 - text_topic_extraction.text_topic_processor - INFO - Topic 311: wbc mono collar
# 2025-03-13 06:16:03,308 - text_topic_extraction.text_topic_processor - INFO - Topic 312: limb arm weak
# 2025-03-13 06:16:03,308 - text_topic_extraction.text_topic_processor - INFO - Topic 313: never smoked doesnt
# 2025-03-13 06:16:03,308 - text_topic_extraction.text_topic_processor - INFO - Topic 314: uti utis pseudomonal
# 2025-03-13 06:16:03,308 - text_topic_extraction.text_topic_processor - INFO - Topic 315: dysuria polyuria oliguria
# 2025-03-13 06:16:03,308 - text_topic_extraction.text_topic_processor - INFO - Topic 316: vascular arteriovenous malformations
# 2025-03-13 06:16:03,309 - text_topic_extraction.text_topic_processor - INFO - Topic 317: abuse substance drug
# 2025-03-13 06:16:03,309 - text_topic_extraction.text_topic_processor - INFO - Topic 318: transfusion cx blood
# 2025-03-13 06:16:03,309 - text_topic_extraction.text_topic_processor - INFO - Topic 319: flow circulation collateral
# 2025-03-13 06:16:03,309 - text_topic_extraction.text_topic_processor - INFO - Topic 320: operation operator type
# 2025-03-13 06:16:03,309 - text_topic_extraction.text_topic_processor - INFO - Topic 321: nursing home resident
# 2025-03-13 06:16:03,309 - text_topic_extraction.text_topic_processor - INFO - Topic 322: creatinine increase rising
# 2025-03-13 06:16:03,309 - text_topic_extraction.text_topic_processor - INFO - Topic 323: coumadin polytrauma bevacizumab
# 2025-03-13 06:16:03,310 - text_topic_extraction.text_topic_processor - INFO - Topic 324: day pack per
# 2025-03-13 06:16:03,310 - text_topic_extraction.text_topic_processor - INFO - Topic 325: function kidney compromised
# 2025-03-13 06:16:03,310 - text_topic_extraction.text_topic_processor - INFO - Topic 326: social history
# 2025-03-13 06:16:03,310 - text_topic_extraction.text_topic_processor - INFO - Topic 327: activities daily activity
# 2025-03-13 06:16:03,310 - text_topic_extraction.text_topic_processor - INFO - Topic 328: malignancy malignant pilocytic
# 2025-03-13 06:16:03,310 - text_topic_extraction.text_topic_processor - INFO - Topic 329: critical noncritical calcific
# 2025-03-13 06:16:03,311 - text_topic_extraction.text_topic_processor - INFO - Topic 330: memory forgetful amnesia
# 2025-03-13 06:16:03,311 - text_topic_extraction.text_topic_processor - INFO - Topic 331: pleural pleura pleurodesis
# 2025-03-13 06:16:03,311 - text_topic_extraction.text_topic_processor - INFO - Topic 332: acidosis metabolic acidemia
# 2025-03-13 06:16:03,311 - text_topic_extraction.text_topic_processor - INFO - Topic 333: masculine
# 2025-03-13 06:16:03,311 - text_topic_extraction.text_topic_processor - INFO - Topic 334: assisted assistedliving living
# 2025-03-13 06:16:03,311 - text_topic_extraction.text_topic_processor - INFO - Topic 335: sensory sensation distortions
# 2025-03-13 06:16:03,311 - text_topic_extraction.text_topic_processor - INFO - Topic 336: clotting clot clots
# 2025-03-13 06:16:03,312 - text_topic_extraction.text_topic_processor - INFO - Topic 337: ivdu ivda interferon
# 2025-03-13 06:16:03,312 - text_topic_extraction.text_topic_processor - INFO - Topic 338: transplant transplantation stem
# 2025-03-13 06:16:03,312 - text_topic_extraction.text_topic_processor - INFO - Topic 339: organ transplant postkidney
# 2025-03-13 06:16:03,312 - text_topic_extraction.text_topic_processor - INFO - Topic 340: accumulation depletion fluid
# 2025-03-13 06:16:03,312 - text_topic_extraction.text_topic_processor - INFO - Topic 341: stenosis aortic root
# 2025-03-13 06:16:03,313 - text_topic_extraction.text_topic_processor - INFO - Topic 342: potassium ph binder
# 2025-03-13 06:16:03,313 - text_topic_extraction.text_topic_processor - INFO - Topic 343: intervention surgical repeat
# 2025-03-13 06:16:03,313 - text_topic_extraction.text_topic_processor - INFO - Topic 344: fracture fractures bone
# 2025-03-13 06:16:03,313 - text_topic_extraction.text_topic_processor - INFO - Topic 345: radiation radiotherapy cystitis
# 2025-03-13 06:16:03,314 - text_topic_extraction.text_topic_processor - INFO - Topic 346: cognitive impairment mild
# 2025-03-13 06:16:03,314 - text_topic_extraction.text_topic_processor - INFO - Topic 347: nitroglycerin glycopeptide sublingual
# 2025-03-13 06:16:03,314 - text_topic_extraction.text_topic_processor - INFO - Topic 348: alcoholism abuse remote
# 2025-03-13 06:16:03,314 - text_topic_extraction.text_topic_processor - INFO - Topic 349: wine than less
# 2025-03-13 06:16:03,314 - text_topic_extraction.text_topic_processor - INFO - Topic 350: longterm advantages stay
# 2025-03-13 06:16:03,315 - text_topic_extraction.text_topic_processor - INFO - Topic 351: risks perioperative risk
# 2025-03-13 06:16:03,315 - text_topic_extraction.text_topic_processor - INFO - Topic 352: moderate drinking drinker
# 2025-03-13 06:16:03,315 - text_topic_extraction.text_topic_processor - INFO - Topic 353: valve bicuspid leakage
# 2025-03-13 06:16:03,315 - text_topic_extraction.text_topic_processor - INFO - Topic 354: solo alone living
# 2025-03-13 06:16:03,316 - text_topic_extraction.text_topic_processor - INFO - Topic 355: fraction ejection 55
# 2025-03-13 06:16:03,316 - text_topic_extraction.text_topic_processor - INFO - Topic 356: hyperlipidemia dyslipidemia
# 2025-03-13 06:16:03,316 - text_topic_extraction.text_topic_processor - INFO - Topic 357: tobacco use no
# 2025-03-13 06:16:03,316 - text_topic_extraction.text_topic_processor - INFO - Topic 358: rectal bleeding vault
# 2025-03-13 06:16:03,316 - text_topic_extraction.text_topic_processor - INFO - Topic 359: 74yearold 70yearold 72yearold
# 2025-03-13 06:16:03,317 - text_topic_extraction.text_topic_processor - INFO - Topic 360: measurement regulator output
# 2025-03-13 06:16:03,317 - text_topic_extraction.text_topic_processor - INFO - Topic 361: occupation title cleaning
# 2025-03-13 06:16:03,317 - text_topic_extraction.text_topic_processor - INFO - Topic 362: ischemia ischemic limb
# 2025-03-13 06:16:03,317 - text_topic_extraction.text_topic_processor - INFO - Topic 363: retention fluid release
# 2025-03-13 06:16:03,317 - text_topic_extraction.text_topic_processor - INFO - Topic 364: fast rate rapid
# 2025-03-13 06:16:03,317 - text_topic_extraction.text_topic_processor - INFO - Topic 365: cohabitation spousal support
# 2025-03-13 06:16:03,317 - text_topic_extraction.text_topic_processor - INFO - Topic 366: leukocytosis mononucleosis borderline
# 2025-03-13 06:16:03,318 - text_topic_extraction.text_topic_processor - INFO - Topic 367: elder elderrelated older
# 2025-03-13 06:16:03,318 - text_topic_extraction.text_topic_processor - INFO - Topic 368: hip fracture joints
# 2025-03-13 06:16:03,318 - text_topic_extraction.text_topic_processor - INFO - Topic 369: agitation intermittent
# 2025-03-13 06:16:03,318 - text_topic_extraction.text_topic_processor - INFO - Topic 370: engineer technician software
# 2025-03-13 06:16:03,318 - text_topic_extraction.text_topic_processor - INFO - Topic 371: nerve neuropathy trigeminal
# 2025-03-13 06:16:03,319 - text_topic_extraction.text_topic_processor - INFO - Topic 372: substancefree substance
# 2025-03-13 06:16:03,319 - text_topic_extraction.text_topic_processor - INFO - Topic 373: stenosis claudication urethral
# 2025-03-13 06:16:03,319 - text_topic_extraction.text_topic_processor - INFO - Topic 374: tremors shaking shaky
# 2025-03-13 06:16:03,319 - text_topic_extraction.text_topic_processor - INFO - Topic 375: difficulty breathing difficulties
# 2025-03-13 06:16:03,319 - text_topic_extraction.text_topic_processor - INFO - Topic 376: age 52 4330
# 2025-03-13 06:16:03,320 - text_topic_extraction.text_topic_processor - INFO - Topic 377: services emergency responders
# 2025-03-13 06:16:03,320 - text_topic_extraction.text_topic_processor - INFO - Topic 378: tomography computed positron
# 2025-03-13 06:16:03,320 - text_topic_extraction.text_topic_processor - INFO - Topic 379: study imaging studies
# 2025-03-13 06:16:03,320 - text_topic_extraction.text_topic_processor - INFO - Topic 380: digestive anorexia tract
# 2025-03-13 06:16:03,320 - text_topic_extraction.text_topic_processor - INFO - Topic 381: antibiotic antibioticassociated coverage
# 2025-03-13 06:16:03,320 - text_topic_extraction.text_topic_processor - INFO - Topic 382: orthopnea atelectasis orthostasis
# 2025-03-13 06:16:03,320 - text_topic_extraction.text_topic_processor - INFO - Topic 383: drainage drain purulent
# 2025-03-13 06:16:03,321 - text_topic_extraction.text_topic_processor - INFO - Topic 384: hospitable cared care
# 2025-03-13 06:16:03,321 - text_topic_extraction.text_topic_processor - INFO - Topic 385: lasix protonix given
# 2025-03-13 06:16:03,321 - text_topic_extraction.text_topic_processor - INFO - Topic 386: chemotherapy postchemotherapy tolerance
# 2025-03-13 06:16:03,321 - text_topic_extraction.text_topic_processor - INFO - Topic 387: refused ama denies
# 2025-03-13 06:16:03,321 - text_topic_extraction.text_topic_processor - INFO - Topic 388: dopamine dobutamine benadryl
# 2025-03-13 06:16:03,321 - text_topic_extraction.text_topic_processor - INFO - Topic 389: marker biomarker markers
# 2025-03-13 06:16:03,321 - text_topic_extraction.text_topic_processor - INFO - Topic 390: surgeries before surgery
# 2025-03-13 06:16:03,322 - text_topic_extraction.text_topic_processor - INFO - Topic 391: esrd ercp er
# 2025-03-13 06:16:03,322 - text_topic_extraction.text_topic_processor - INFO - Topic 392: hepatitis serologies hepatitisfree
# 2025-03-13 06:16:03,322 - text_topic_extraction.text_topic_processor - INFO - Topic 393: anticoagulation anticoagulants anticoagulant
# 2025-03-13 06:16:03,322 - text_topic_extraction.text_topic_processor - INFO - Topic 394: occurrences occurrence events
# 2025-03-13 06:16:03,322 - text_topic_extraction.text_topic_processor - INFO - Topic 395: gender gendermale male
# 2025-03-13 06:16:03,322 - text_topic_extraction.text_topic_processor - INFO - Topic 396: anemia uremia cobalamin
# 2025-03-13 06:16:03,322 - text_topic_extraction.text_topic_processor - INFO - Topic 397: failure decompensated classification
# 2025-03-13 06:16:03,323 - text_topic_extraction.text_topic_processor - INFO - Topic 398: diaphoretic anesthetic paresthesia
# 2025-03-13 06:16:03,323 - text_topic_extraction.text_topic_processor - INFO - Topic 399: lobe lobectomy fossa
# 2025-03-13 06:16:03,323 - text_topic_extraction.text_topic_processor - INFO - Topic 400: regurgitation mitral tricuspid
# ...
# 2025-03-13 06:16:03,621 - text_topic_extraction.text_topic_processor - INFO - Topic 1179: varices gastric esophageal
# 2025-03-13 06:16:03,621 - text_topic_extraction.text_topic_processor - INFO - Topic 1180: cirrhosis cryptogenic etoh
# 2025-03-13 06:16:03,622 - text_topic_extraction.text_topic_processor - INFO - Topic 1181: diarrhea postprandial baseline
# 2025-03-13 06:16:03,622 - text_topic_extraction.text_topic_processor - INFO - Topic 1182: lowgrade grade fever
# 2025-03-13 06:16:03,622 - text_topic_extraction.text_topic_processor - INFO - Topic 1183: collision vehicle motor
# 2025-03-13 06:16:03,622 - text_topic_extraction.text_topic_processor - INFO - Topic 1184: tpa twi dopa
# 2025-03-13 06:16:03,622 - text_topic_extraction.text_topic_processor - INFO - Topic 1185: resuscitate do not
# 2025-03-13 06:16:03,622 - text_topic_extraction.text_topic_processor - INFO - Topic 1186: physiological parameters readings
# 2025-03-13 06:16:03,623 - text_topic_extraction.text_topic_processor - INFO - Topic 1187: visit visits hospital
# 2025-03-13 06:16:03,623 - text_topic_extraction.text_topic_processor - INFO - Topic 1188: device base pump
# 2025-03-13 06:16:03,623 - text_topic_extraction.text_topic_processor - INFO - Topic 1189: 65 69yearold old
# 2025-03-13 06:16:03,624 - text_topic_extraction.text_topic_processor - INFO - Topic 1190: afib vfib
# 2025-03-13 06:16:03,624 - text_topic_extraction.text_topic_processor - INFO - Topic 1191: over age 90
# 2025-03-13 06:16:03,624 - text_topic_extraction.text_topic_processor - INFO - Topic 1192: creatinine elevated
# 2025-03-13 06:16:03,624 - text_topic_extraction.text_topic_processor - INFO - Topic 1193: acetylcysteine acetylsalicylic salicylate
# 2025-03-13 06:16:03,624 - text_topic_extraction.text_topic_processor - INFO - Topic 1194: antiarrhythmic medication drug
# 2025-03-13 06:16:03,624 - text_topic_extraction.text_topic_processor - INFO - Topic 1195: caretaker groundskeeper nanny
# 2025-03-13 06:16:03,625 - text_topic_extraction.text_topic_processor - INFO - Topic 1196: partner romantic
# 2025-03-13 06:16:03,625 - text_topic_extraction.text_topic_processor - INFO - Topic 1197: cipro cisplatin carbapenem
# 2025-03-13 06:16:03,625 - text_topic_extraction.text_topic_processor - INFO - Topic 1198: wellbeing psychological
# 2025-03-13 06:16:03,625 - text_topic_extraction.text_topic_processor - INFO - Topic 1199: regurgitation aortic
# 2025-03-13 06:16:03,626 - text_topic_extraction.text_topic_processor - INFO - Topic 1200: 81f 60f 52f
# 2025-03-13 06:16:03,626 - text_topic_extraction.text_topic_processor - INFO - Topic 1201: communication methods communicating
# 2025-03-13 06:16:03,626 - text_topic_extraction.text_topic_processor - INFO - Topic 1202: abdominal ultrasound imaging
# 2025-03-13 06:16:03,626 - text_topic_extraction.text_topic_processor - INFO - Topic 1203: deep thrombosis vein
# 2025-03-13 06:16:03,627 - text_topic_extraction.text_topic_processor - INFO - Topic 1204: products product collection
# 2025-03-13 06:16:03,627 - text_topic_extraction.text_topic_processor - INFO - Topic 1205: highrisk atrisk individual
# 2025-03-13 06:16:03,627 - text_topic_extraction.text_topic_processor - INFO - Topic 1206: nonsmoker
# 2025-03-13 06:16:03,627 - text_topic_extraction.text_topic_processor - INFO - Topic 1207: legs hot feet
# 2025-03-13 06:16:03,627 - text_topic_extraction.text_topic_processor - INFO - Topic 1208: smokefree smoke free
# 2025-03-13 06:16:03,628 - text_topic_extraction.text_topic_processor - INFO - Topic 1209: immobility debility amenable
# 2025-03-13 06:16:03,628 - text_topic_extraction.text_topic_processor - INFO - Topic 1210: teetotaler tee
# 2025-03-13 06:16:03,628 - text_topic_extraction.text_topic_processor - INFO - Topic 1211: adrenaline heartbeat steady
# 2025-03-13 06:16:03,628 - text_topic_extraction.text_topic_processor - INFO - Topic 1212: mechanic repairman motorcycle
# 2025-03-13 06:16:03,628 - text_topic_extraction.text_topic_processor - INFO - Topic 1213: occlusion occluded flesh
# 2025-03-13 06:16:03,629 - text_topic_extraction.text_topic_processor - INFO - Topic 1214: morning today afternoon
# 2025-03-13 06:16:03,629 - text_topic_extraction.text_topic_processor - INFO - Topic 1215: iph rh ipf
# 2025-03-13 06:16:03,629 - text_topic_extraction.text_topic_processor - INFO - Topic 1216: paralysis initial
# 2025-03-13 06:16:03,630 - text_topic_extraction.text_topic_processor - INFO - Topic 1217: plavix plasminogen activator
# 2025-03-13 06:16:03,630 - text_topic_extraction.text_topic_processor - INFO - Topic 1218: bilirubin direct total
# 2025-03-13 06:16:03,631 - text_topic_extraction.text_topic_processor - INFO - Topic 1219: ammonia 266 level
# 2025-03-13 06:16:03,631 - text_topic_extraction.text_topic_processor - INFO - Topic 1220: date admission recent
# 2025-03-13 06:16:03,631 - text_topic_extraction.text_topic_processor - INFO - Topic 1221: dysphagia evaluation
# 2025-03-13 06:16:03,632 - text_topic_extraction.text_topic_processor - INFO - Topic 1222: prostate prostatectomy hyperplasia
# 2025-03-13 06:16:03,632 - text_topic_extraction.text_topic_processor - INFO - Topic 1223: loss significant recent
# 2025-03-13 06:16:03,632 - text_topic_extraction.text_topic_processor - INFO - Topic 1224: corticosteroid corticosteroids adjustment
# 2025-03-13 06:16:03,633 - text_topic_extraction.text_topic_processor - INFO - Topic 1225: nondrug user nonprescription
# 2025-03-13 06:16:03,633 - text_topic_extraction.text_topic_processor - INFO - Topic 1226: as ast aspirated
# 2025-03-13 06:16:03,634 - text_topic_extraction.text_topic_processor - INFO - Topic 1227: nephropathy kidney chronic
# 2025-03-13 06:16:03,634 - text_topic_extraction.text_topic_processor - INFO - Topic 1228: coughing up cough
# 2025-03-13 06:16:03,635 - text_topic_extraction.text_topic_processor - INFO - Topic 1229: wine gin bottle
# 2025-03-13 06:16:03,635 - text_topic_extraction.text_topic_processor - INFO - Topic 1230: leukemia myeloma myeloid
# 2025-03-13 06:16:03,635 - text_topic_extraction.text_topic_processor - INFO - Topic 1231: decline overall functional
# 2025-03-13 06:16:03,636 - text_topic_extraction.text_topic_processor - INFO - Topic 1232: aggravated acute pain
# 2025-03-13 06:16:03,636 - text_topic_extraction.text_topic_processor - INFO - Topic 1233: pensioner pensioned retirement
# 2025-03-13 06:16:03,636 - text_topic_extraction.text_topic_processor - INFO - Topic 1234: septic arthritis joint
# 2025-03-13 06:16:03,636 - text_topic_extraction.text_topic_processor - INFO - Topic 1235: walker hiker holter
# 2025-03-13 06:16:03,636 - text_topic_extraction.text_topic_processor - INFO - Topic 1236: habits habitual drinking
# 2025-03-13 06:16:03,637 - text_topic_extraction.text_topic_processor - INFO - Topic 1237: admission admissions medical
# 2025-03-13 06:16:03,637 - text_topic_extraction.text_topic_processor - INFO - Topic 1238: admissions previous recent
# 2025-03-13 06:16:03,637 - text_topic_extraction.text_topic_processor - INFO - Topic 1239: fulminant hepatic liver
# 2025-03-13 06:16:03,637 - text_topic_extraction.text_topic_processor - INFO - Topic 1240: racing heart no
# 2025-03-13 06:16:03,638 - text_topic_extraction.text_topic_processor - INFO - Topic 1241: retired
# 2025-03-13 06:16:03,638 - text_topic_extraction.text_topic_processor - INFO - Topic 1242: sleepy nap
# 2025-03-13 06:16:03,639 - text_topic_extraction.text_topic_processor - INFO - Topic 1243: egd
# 2025-03-13 06:16:03,639 - text_topic_extraction.text_topic_processor - INFO - Topic 1244: microbiological organism microbiologic
# 2025-03-13 06:16:03,640 - text_topic_extraction.text_topic_processor - INFO - Topic 1245: volume tidal albumin
# 2025-03-13 06:16:03,640 - text_topic_extraction.text_topic_processor - INFO - Topic 1246: quantity amount minimal
# 2025-03-13 06:16:03,640 - text_topic_extraction.text_topic_processor - INFO - Topic 1247: dull prolonged chest
# 2025-03-13 06:16:03,640 - text_topic_extraction.text_topic_processor - INFO - Topic 1248: appetite poor low
# 2025-03-13 06:16:03,641 - text_topic_extraction.text_topic_processor - INFO - Topic 1249: client consultant consulting
# 2025-03-13 06:16:03,641 - text_topic_extraction.text_topic_processor - INFO - Topic 1250: pounds lbs 4pound
# 2025-03-13 06:16:03,641 - text_topic_extraction.text_topic_processor - INFO - Topic 1251: obstruction bowel condition
# 2025-03-13 06:16:03,641 - text_topic_extraction.text_topic_processor - INFO - Topic 1252: primary doctors physician
# 2025-03-13 06:16:03,641 - text_topic_extraction.text_topic_processor - INFO - Topic 1253: radiating radiation pain
# 2025-03-13 06:16:03,642 - text_topic_extraction.text_topic_processor - INFO - Topic 1254: effusion pericardial pericardiocentesis
# 2025-03-13 06:16:03,642 - text_topic_extraction.text_topic_processor - INFO - Topic 1255: delirium coma comatose
# 2025-03-13 06:16:03,643 - text_topic_extraction.text_topic_processor - INFO - Topic 1256: pneumothorax hemothorax left
# 2025-03-13 06:16:03,643 - text_topic_extraction.text_topic_processor - INFO - Topic 1257: consciousness altered
# 2025-03-13 06:16:03,644 - text_topic_extraction.text_topic_processor - INFO - Topic 1258: transfer clinical medical
# 2025-03-13 06:16:03,644 - text_topic_extraction.text_topic_processor - INFO - Topic 1259: 73 69 74
# 2025-03-13 06:16:03,644 - text_topic_extraction.text_topic_processor - INFO - Topic 1260: ativan atrovent sublingual
# 2025-03-13 06:16:03,645 - text_topic_extraction.text_topic_processor - INFO - Topic 1261: chemo chemoradiation after
# 2025-03-13 06:16:03,645 - text_topic_extraction.text_topic_processor - INFO - Topic 1262: ease effort at
# 2025-03-13 06:16:03,646 - text_topic_extraction.text_topic_processor - INFO - Topic 1263: recreational drugs drug
# 2025-03-13 06:16:03,646 - text_topic_extraction.text_topic_processor - INFO - Topic 1264: ua positive
# 2025-03-13 06:16:03,647 - text_topic_extraction.text_topic_processor - INFO - Topic 1265: rectum bright per
# 2025-03-13 06:16:03,647 - text_topic_extraction.text_topic_processor - INFO - Topic 1266: technician responders technicians
# 2025-03-13 06:16:03,705 - text_topic_extraction.text_topic_processor - INFO - Topic 1267: spread skeletal spreads
# 2025-03-13 06:16:03,706 - text_topic_extraction.text_topic_processor - INFO - Topic 1268: cannabis marijuana weed
# 2025-03-13 06:16:03,706 - text_topic_extraction.text_topic_processor - INFO - Topic 1269: watery bloody bedridden
# 2025-03-13 06:16:03,706 - text_topic_extraction.text_topic_processor - INFO - Topic 1270: selfreport selfreferred selfpresented
# 2025-03-13 06:16:03,706 - text_topic_extraction.text_topic_processor - INFO - Topic 1271: extremity lower ultrasonography
# 2025-03-13 06:16:03,707 - text_topic_extraction.text_topic_processor - INFO - Topic 1272: 66 66yearold year
# 2025-03-13 06:16:03,707 - text_topic_extraction.text_topic_processor - INFO - Topic 1273: mediumsized mb fits
# 2025-03-13 06:16:03,707 - text_topic_extraction.text_topic_processor - INFO - Topic 1274: secretions secretion respiratory
# 2025-03-13 06:16:03,707 - text_topic_extraction.text_topic_processor - INFO - Topic 1275: dexamethasone solumedrol dextrose
# 2025-03-13 06:16:03,707 - text_topic_extraction.text_topic_processor - INFO - Topic 1276: employment job status
# 2025-03-13 06:16:03,707 - text_topic_extraction.text_topic_processor - INFO - Topic 1277: after passed out
# 2025-03-13 06:16:03,707 - text_topic_extraction.text_topic_processor - INFO - Topic 1278: conditions living poor
# 2025-03-13 06:16:03,708 - text_topic_extraction.text_topic_processor - INFO - Topic 1279: heavy previously excessive
# 2025-03-13 06:16:03,708 - text_topic_extraction.text_topic_processor - INFO - Topic 1280: immediate injury acute
# 2025-03-13 06:16:03,708 - text_topic_extraction.text_topic_processor - INFO - Topic 1281: contrast iodinated opacity
# 2025-03-13 06:16:03,708 - text_topic_extraction.text_topic_processor - INFO - Topic 1282: ache aches minor
# 2025-03-13 06:16:03,708 - text_topic_extraction.text_topic_processor - INFO - Topic 1283: bilingual translator sublingual
# 2025-03-13 06:16:03,709 - text_topic_extraction.text_topic_processor - INFO - Topic 1284: strokes stroke previous
# 2025-03-13 06:16:03,709 - text_topic_extraction.text_topic_processor - INFO - Topic 1285: massachusetts ma western
# 2025-03-13 06:16:03,709 - text_topic_extraction.text_topic_processor - INFO - Topic 1286: medflighted airlifted flight
# 2025-03-13 06:16:03,709 - text_topic_extraction.text_topic_processor - INFO - Topic 1287: critical unit care
# 2025-03-13 06:16:03,709 - text_topic_extraction.text_topic_processor - INFO - Topic 1288: etoh denies denied
# 2025-03-13 06:16:03,709 - text_topic_extraction.text_topic_processor - INFO - Topic 1289: presence handling familyoriented
# 2025-03-13 06:16:03,710 - text_topic_extraction.text_topic_processor - INFO - Topic 1290: workup upchuck extensive
# 2025-03-13 06:16:03,710 - text_topic_extraction.text_topic_processor - INFO - Topic 1291: hospital1 18 789
# 2025-03-13 06:16:03,710 - text_topic_extraction.text_topic_processor - INFO - Topic 1292: antibiotics iv antibiotic
# 2025-03-13 06:16:03,710 - text_topic_extraction.text_topic_processor - INFO - Topic 1293: coronary artery disease
# 2025-03-13 06:16:03,710 - text_topic_extraction.text_topic_processor - INFO - Topic 1294: shock treatment
# 2025-03-13 06:16:03,710 - text_topic_extraction.text_topic_processor - INFO - Topic 1295: etoposide amiodarone adenosine
# 2025-03-13 06:16:03,711 - text_topic_extraction.text_topic_processor - INFO - Topic 1296: spanish speaking portuguese
# 2025-03-13 06:16:03,711 - text_topic_extraction.text_topic_processor - INFO - Topic 1297: morbid obesity
# 2025-03-13 06:16:03,711 - text_topic_extraction.text_topic_processor - INFO - Topic 1298: consult general consultation
# 2025-03-13 06:16:03,711 - text_topic_extraction.text_topic_processor - INFO - Topic 1299: homeless homelessness status
# 2025-03-13 06:16:03,711 - text_topic_extraction.text_topic_processor - INFO - Topic 1300: nonhospital treatment medical
# 2025-03-13 06:16:03,711 - text_topic_extraction.text_topic_processor - INFO - Topic 1301: sample tissue sampling
# 2025-03-13 06:16:03,711 - text_topic_extraction.text_topic_processor - INFO - Topic 1302: severity medium average
# 2025-03-13 06:16:03,712 - text_topic_extraction.text_topic_processor - INFO - Topic 1303: obstructed alleviation obtundation
# 2025-03-13 06:16:03,712 - text_topic_extraction.text_topic_processor - INFO - Topic 1304: separated separation stranding
# 2025-03-13 06:16:03,712 - text_topic_extraction.text_topic_processor - INFO - Topic 1305: fall risk incident
# 2025-03-13 06:16:03,712 - text_topic_extraction.text_topic_processor - INFO - Topic 1306: 68 64yearold 64
# 2025-03-13 06:16:03,713 - text_topic_extraction.text_topic_processor - INFO - Topic 1307: hypoxemia hypoxemic hydromorphone
# 2025-03-13 06:16:03,713 - text_topic_extraction.text_topic_processor - INFO - Topic 1308: aide home assistance
# 2025-03-13 06:16:03,713 - text_topic_extraction.text_topic_processor - INFO - Topic 1309: clammy clamminess clumsiness
# 2025-03-13 06:16:03,713 - text_topic_extraction.text_topic_processor - INFO - Topic 1310: refusal treatment medication
# 2025-03-13 06:16:03,713 - text_topic_extraction.text_topic_processor - INFO - Topic 1311: intraperitoneal internal diffuse
# 2025-03-13 06:16:03,714 - text_topic_extraction.text_topic_processor - INFO - Topic 1312: access arterial vascular
# 2025-03-13 06:16:03,714 - text_topic_extraction.text_topic_processor - INFO - Topic 1313: 56 59 52
# 2025-03-13 06:16:03,714 - text_topic_extraction.text_topic_processor - INFO - Topic 1314: lsided symmetric doublesided
# 2025-03-13 06:16:03,714 - text_topic_extraction.text_topic_processor - INFO - Topic 1315: preceding unchanged new
# 2025-03-13 06:16:03,714 - text_topic_extraction.text_topic_processor - INFO - Topic 1316: comprehensive assessment
# 2025-03-13 06:16:03,715 - text_topic_extraction.text_topic_processor - INFO - Topic 1317: geriatric concerns care
# 2025-03-13 06:16:03,715 - text_topic_extraction.text_topic_processor - INFO - Topic 1318: nonsmoker

# %%
batch_size = 100
all_topic_questions = []
for i in range(0, len(topics), batch_size):
    topic_batch = topics[i:i + batch_size]
    topic_questions = processor._generate_questions(
        topics=topic_batch,
        question_generator=question_generator,
    )
    print("topic question ex:", topic_questions[0])
    print("num topics", len(topic_questions))
    all_topic_questions += topic_questions
# Out:
# 2025-03-13 07:06:41,788 - text_topic_extraction.text_topic_processor - INFO - Generating questions for 100 topics
# 2025-03-13 07:07:25,019 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-13 07:07:25,073 - text_topic_extraction.cache.cache_manager - INFO - Stored response in cache with key 2db52454ab...
# 2025-03-13 07:07:25,075 - text_topic_extraction.text_topic_processor - INFO - Generated 100 questions
# 2025-03-13 07:07:25,075 - text_topic_extraction.text_topic_processor - INFO - Question for topic 0: Is the patient described as an elderly or aging person?
# 2025-03-13 07:07:25,075 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1: Is the patient identified as a male cyclist?
# 2025-03-13 07:07:25,075 - text_topic_extraction.text_topic_processor - INFO - Question for topic 2: Is the patient's social history unknown?
# 2025-03-13 07:07:25,075 - text_topic_extraction.text_topic_processor - INFO - Question for topic 3: Is the patient referred to as a senior gentleman or man?
# 2025-03-13 07:07:25,076 - text_topic_extraction.text_topic_processor - INFO - Question for topic 4: Is the patient described as a man or lad?
# 2025-03-13 07:07:25,076 - text_topic_extraction.text_topic_processor - INFO - Question for topic 5: Is the patient a 75-year-old female or girl?
# 2025-03-13 07:07:25,076 - text_topic_extraction.text_topic_processor - INFO - Question for topic 6: Is the patient referred to as a woman or lady?
# 2025-03-13 07:07:25,076 - text_topic_extraction.text_topic_processor - INFO - Question for topic 7: Are lifestyle factors mentioned in the patient's notes?
# 2025-03-13 07:07:25,076 - text_topic_extraction.text_topic_processor - INFO - Question for topic 8: Is the patient described as middle-aged or middle-class?
# 2025-03-13 07:07:25,076 - text_topic_extraction.text_topic_processor - INFO - Question for topic 9: Does the patient have hypertension or take antihypertensive medication?
# 2025-03-13 07:07:25,077 - text_topic_extraction.text_topic_processor - INFO - Question for topic 10: Does the patient experience dyspnea or tachypnea?
# 2025-03-13 07:07:25,077 - text_topic_extraction.text_topic_processor - INFO - Question for topic 11: Is there mention of the patient having an estranged spouse?
# 2025-03-13 07:07:25,077 - text_topic_extraction.text_topic_processor - INFO - Question for topic 12: Is there a mention of a tumor or cancer in the patient's notes?
# 2025-03-13 07:07:25,077 - text_topic_extraction.text_topic_processor - INFO - Question for topic 13: Is the patient's medical history described as complex?
# 2025-03-13 07:07:25,077 - text_topic_extraction.text_topic_processor - INFO - Question for topic 14: Does the patient experience shortness of breath?
# 2025-03-13 07:07:25,078 - text_topic_extraction.text_topic_processor - INFO - Question for topic 15: Is there mention of coronary artery disease in the patient's notes?
# 2025-03-13 07:07:25,078 - text_topic_extraction.text_topic_processor - INFO - Question for topic 16: Are treatment regimen options discussed in the patient's notes?
# 2025-03-13 07:07:25,078 - text_topic_extraction.text_topic_processor - INFO - Question for topic 17: Is the patient described as an adult or mature individual?
# 2025-03-13 07:07:25,078 - text_topic_extraction.text_topic_processor - INFO - Question for topic 18: Is there a planned surgery or thrombectomy for the patient?
# 2025-03-13 07:07:25,078 - text_topic_extraction.text_topic_processor - INFO - Question for topic 19: Does the patient experience hypotension or postural hypotension?
# 2025-03-13 07:07:25,078 - text_topic_extraction.text_topic_processor - INFO - Question for topic 20: Is there mention of high blood pressure in the patient's notes?
# 2025-03-13 07:07:25,079 - text_topic_extraction.text_topic_processor - INFO - Question for topic 21: Is there mention of antibiotic use in the patient's notes?
# 2025-03-13 07:07:25,079 - text_topic_extraction.text_topic_processor - INFO - Question for topic 22: Does the patient experience nausea or sickness?
# 2025-03-13 07:07:25,079 - text_topic_extraction.text_topic_processor - INFO - Question for topic 23: Is there mention of CAD or non-CAD in the patient's notes?
# 2025-03-13 07:07:25,079 - text_topic_extraction.text_topic_processor - INFO - Question for topic 24: Does the patient experience fatigue or exhaustion?
# 2025-03-13 07:07:25,079 - text_topic_extraction.text_topic_processor - INFO - Question for topic 25: Is there mention of tobacco or cigarette use in the patient's notes?
# 2025-03-13 07:07:25,079 - text_topic_extraction.text_topic_processor - INFO - Question for topic 26: Is there mention of hospitalization in the patient's notes?
# 2025-03-13 07:07:25,080 - text_topic_extraction.text_topic_processor - INFO - Question for topic 27: Does the patient experience abdominal pain or tenderness?
# 2025-03-13 07:07:25,080 - text_topic_extraction.text_topic_processor - INFO - Question for topic 28: Does the patient experience vomiting or throwing up?
# 2025-03-13 07:07:25,080 - text_topic_extraction.text_topic_processor - INFO - Question for topic 29: Does the patient have a fever or feel feverish?
# 2025-03-13 07:07:25,080 - text_topic_extraction.text_topic_processor - INFO - Question for topic 30: Is the patient described by their age, such as 61 or 47 years old?
# 2025-03-13 07:07:25,080 - text_topic_extraction.text_topic_processor - INFO - Question for topic 31: Is there mention of low blood pressure in the patient's notes?
# 2025-03-13 07:07:25,081 - text_topic_extraction.text_topic_processor - INFO - Question for topic 32: Is there mention of smoking a pipe in the patient's notes?
# 2025-03-13 07:07:25,081 - text_topic_extraction.text_topic_processor - INFO - Question for topic 33: Is there mention of cardiovascular or heart disease in the patient's notes?
# 2025-03-13 07:07:25,081 - text_topic_extraction.text_topic_processor - INFO - Question for topic 34: Is the patient described as married or in a marriage?
# 2025-03-13 07:07:25,081 - text_topic_extraction.text_topic_processor - INFO - Question for topic 35: Is the patient's condition described as stable or having stability?
# 2025-03-13 07:07:25,081 - text_topic_extraction.text_topic_processor - INFO - Question for topic 36: Does the patient experience chest pain or twinges?
# 2025-03-13 07:07:25,081 - text_topic_extraction.text_topic_processor - INFO - Question for topic 37: Are vital signs or observations mentioned in the patient's notes?
# 2025-03-13 07:07:25,082 - text_topic_extraction.text_topic_processor - INFO - Question for topic 38: Is the patient's living situation or life circumstances discussed?
# 2025-03-13 07:07:25,082 - text_topic_extraction.text_topic_processor - INFO - Question for topic 39: Is there mention of the patient's family or relatives in the notes?
# 2025-03-13 07:07:25,082 - text_topic_extraction.text_topic_processor - INFO - Question for topic 40: Has the patient recently quit smoking?
# 2025-03-13 07:07:25,082 - text_topic_extraction.text_topic_processor - INFO - Question for topic 41: Does the patient experience headaches or bifrontal pain?
# 2025-03-13 07:07:25,082 - text_topic_extraction.text_topic_processor - INFO - Question for topic 42: Is there mention of alcohol use or drinking in the patient's notes?
# 2025-03-13 07:07:25,082 - text_topic_extraction.text_topic_processor - INFO - Question for topic 43: Is there mention of diabetes or diabetic supplies in the patient's notes?
# 2025-03-13 07:07:25,082 - text_topic_extraction.text_topic_processor - INFO - Question for topic 44: Is the patient's history documented or provided by a historian?
# 2025-03-13 07:07:25,083 - text_topic_extraction.text_topic_processor - INFO - Question for topic 45: Does the patient experience weakness or frailty?
# 2025-03-13 07:07:25,083 - text_topic_extraction.text_topic_processor - INFO - Question for topic 46: Does the patient experience discomfort or spasticity?
# 2025-03-13 07:07:25,083 - text_topic_extraction.text_topic_processor - INFO - Question for topic 47: Is there mention of an interhospital transfer in the patient's notes?
# 2025-03-13 07:07:25,083 - text_topic_extraction.text_topic_processor - INFO - Question for topic 48: Is there mention of alcohol use or misuse in the patient's notes?
# 2025-03-13 07:07:25,083 - text_topic_extraction.text_topic_processor - INFO - Question for topic 49: Is there mention of coffee ground emesis in the patient's notes?
# 2025-03-13 07:07:25,084 - text_topic_extraction.text_topic_processor - INFO - Question for topic 50: Is there mention of family support or parents in the patient's notes?
# 2025-03-13 07:07:25,084 - text_topic_extraction.text_topic_processor - INFO - Question for topic 51: Are evaluations or assessments mentioned in the patient's notes?
# 2025-03-13 07:07:25,084 - text_topic_extraction.text_topic_processor - INFO - Question for topic 52: Is there mention of an infection or meningitis in the patient's notes?
# 2025-03-13 07:07:25,084 - text_topic_extraction.text_topic_processor - INFO - Question for topic 53: Is there mention of atrial fibrillation in the patient's notes?
# 2025-03-13 07:07:25,084 - text_topic_extraction.text_topic_processor - INFO - Question for topic 54: Is there mention of a stroke or use of a cane in the patient's notes?
# 2025-03-13 07:07:25,084 - text_topic_extraction.text_topic_processor - INFO - Question for topic 55: Is there mention of trauma or PTSD in the patient's notes?
# 2025-03-13 07:07:25,085 - text_topic_extraction.text_topic_processor - INFO - Question for topic 56: Is there mention of an invasive or minimally invasive procedure in the patient's notes?
# 2025-03-13 07:07:25,085 - text_topic_extraction.text_topic_processor - INFO - Question for topic 57: Is there mention of an emergency department evaluation in the patient's notes?
# 2025-03-13 07:07:25,085 - text_topic_extraction.text_topic_processor - INFO - Question for topic 58: Is there mention of pneumonia or aspiration in the patient's notes?
# 2025-03-13 07:07:25,085 - text_topic_extraction.text_topic_processor - INFO - Question for topic 59: Is there mention of exercise or physical activity in the patient's notes?
# 2025-03-13 07:07:25,085 - text_topic_extraction.text_topic_processor - INFO - Question for topic 60: Is there mention of medication or medication reactions in the patient's notes?
# 2025-03-13 07:07:25,085 - text_topic_extraction.text_topic_processor - INFO - Question for topic 61: Is there mention of tobacco use or smoking in the patient's notes?
# 2025-03-13 07:07:25,086 - text_topic_extraction.text_topic_processor - INFO - Question for topic 62: Is there mention of offspring or descendants in the patient's notes?
# 2025-03-13 07:07:25,086 - text_topic_extraction.text_topic_processor - INFO - Question for topic 63: Is there mention of lifestyle choices or non-revitalization in the patient's notes?
# 2025-03-13 07:07:25,086 - text_topic_extraction.text_topic_processor - INFO - Question for topic 64: Is there mention of swelling or pulsatile symptoms in the patient's notes?
# 2025-03-13 07:07:25,086 - text_topic_extraction.text_topic_processor - INFO - Question for topic 65: Is there mention of imaging or radiographic procedures in the patient's notes?
# 2025-03-13 07:07:25,087 - text_topic_extraction.text_topic_processor - INFO - Question for topic 66: Is there mention of angina pectoris in the patient's notes?
# 2025-03-13 07:07:25,087 - text_topic_extraction.text_topic_processor - INFO - Question for topic 67: Is there mention of an intensive care unit in the patient's notes?
# 2025-03-13 07:07:25,087 - text_topic_extraction.text_topic_processor - INFO - Question for topic 68: Is there mention of a productive cough in the patient's notes?
# 2025-03-13 07:07:25,087 - text_topic_extraction.text_topic_processor - INFO - Question for topic 69: Is there mention of edema or ankle swelling in the patient's notes?
# 2025-03-13 07:07:25,087 - text_topic_extraction.text_topic_processor - INFO - Question for topic 70: Does the patient experience queasiness or queasy feelings?
# 2025-03-13 07:07:25,088 - text_topic_extraction.text_topic_processor - INFO - Question for topic 71: Is there mention of CHF or DCHF in the patient's notes?
# 2025-03-13 07:07:25,088 - text_topic_extraction.text_topic_processor - INFO - Question for topic 72: Is there mention of education or college in the patient's notes?
# 2025-03-13 07:07:25,088 - text_topic_extraction.text_topic_processor - INFO - Question for topic 73: Is there mention of a CT scan in the patient's notes?
# 2025-03-13 07:07:25,088 - text_topic_extraction.text_topic_processor - INFO - Question for topic 74: Is there mention of an elective admission in the patient's notes?
# 2025-03-13 07:07:25,088 - text_topic_extraction.text_topic_processor - INFO - Question for topic 75: Is there mention of an ICU admission in the patient's notes?
# 2025-03-13 07:07:25,089 - text_topic_extraction.text_topic_processor - INFO - Question for topic 76: Is there mention of urgent or preventive care in the patient's notes?
# 2025-03-13 07:07:25,089 - text_topic_extraction.text_topic_processor - INFO - Question for topic 77: Is the patient described as a former smoker or firefighter?
# 2025-03-13 07:07:25,089 - text_topic_extraction.text_topic_processor - INFO - Question for topic 78: Is there mention of a complex past medical history in the patient's notes?
# 2025-03-13 07:07:25,089 - text_topic_extraction.text_topic_processor - INFO - Question for topic 79: Is the patient described as being over 84 years old?
# 2025-03-13 07:07:25,090 - text_topic_extraction.text_topic_processor - INFO - Question for topic 80: Does the patient experience diarrhea or watery stools?
# 2025-03-13 07:07:25,090 - text_topic_extraction.text_topic_processor - INFO - Question for topic 81: Is there mention of recovery or remission in the patient's notes?
# 2025-03-13 07:07:25,090 - text_topic_extraction.text_topic_processor - INFO - Question for topic 82: Is there mention of gender identity or orientation in the patient's notes?
# 2025-03-13 07:07:25,090 - text_topic_extraction.text_topic_processor - INFO - Question for topic 83: Is there mention of IV fluids or Solu-Medrol in the patient's notes?
# 2025-03-13 07:07:25,090 - text_topic_extraction.text_topic_processor - INFO - Question for topic 84: Does the patient experience anxiety or photophobia?
# 2025-03-13 07:07:25,091 - text_topic_extraction.text_topic_processor - INFO - Question for topic 85: Is there mention of oxygen saturation or paleness in the patient's notes?
# 2025-03-13 07:07:25,091 - text_topic_extraction.text_topic_processor - INFO - Question for topic 86: Is there mention of ETOH use or incoherence in the patient's notes?
# 2025-03-13 07:07:25,091 - text_topic_extraction.text_topic_processor - INFO - Question for topic 87: Is the patient admitted and eligible for a program or treatment?
# 2025-03-13 07:07:25,091 - text_topic_extraction.text_topic_processor - INFO - Question for topic 88: Is there mention of seizures or epilepsy in the patient's notes?
# 2025-03-13 07:07:25,091 - text_topic_extraction.text_topic_processor - INFO - Question for topic 89: Is there mention of kidney failure or renal issues in the patient's notes?
# 2025-03-13 07:07:25,092 - text_topic_extraction.text_topic_processor - INFO - Question for topic 90: Is there mention of an acute episode or need for care in the patient's notes?
# 2025-03-13 07:07:25,092 - text_topic_extraction.text_topic_processor - INFO - Question for topic 91: Is there mention of a strategy or manager in the patient's notes?
# 2025-03-13 07:07:25,092 - text_topic_extraction.text_topic_processor - INFO - Question for topic 92: Is there mention of tachycardia or supraventricular tachycardia in the patient's notes?
# 2025-03-13 07:07:25,092 - text_topic_extraction.text_topic_processor - INFO - Question for topic 93: Is there mention of intubation or reintubation in the patient's notes?
# 2025-03-13 07:07:25,092 - text_topic_extraction.text_topic_processor - INFO - Question for topic 94: Is there mention of lung sounds or pulmonary issues in the patient's notes?
# 2025-03-13 07:07:25,093 - text_topic_extraction.text_topic_processor - INFO - Question for topic 95: Is there mention of an initial assessment or tool in the patient's notes?
# 2025-03-13 07:07:25,093 - text_topic_extraction.text_topic_processor - INFO - Question for topic 96: Is there mention of elevated temperature or CO2 in the patient's notes?
# 2025-03-13 07:07:25,093 - text_topic_extraction.text_topic_processor - INFO - Question for topic 97: Is there mention of surgery or an implant in the patient's notes?
# 2025-03-13 07:07:25,093 - text_topic_extraction.text_topic_processor - INFO - Question for topic 98: Is the patient described as abstinent from drugs?
# 2025-03-13 07:07:25,093 - text_topic_extraction.text_topic_processor - INFO - Question for topic 99: Is there mention of drinking on the weekend in the patient's notes?
# 2025-03-13 07:07:25,094 - text_topic_extraction.text_topic_processor - INFO - Generating questions for 100 topics
# topic question ex: topic_id=0 topic_name='elderly aging person' question='Is the patient described as an elderly or aging person?' keywords=['elderly', 'aging', 'person', 'population', 'worker', 'mother', 'aged', '', '', ''] keyword_scores=[0.13809806533186764, 0.010444242025935841, 0.009521822757240776, 0.008182954483843301, 0.007694280806424764, 0.007232136342474878, 0.005685869822041315, 1e-05, 1e-05, 1e-05]
# num topics 100
# 2025-03-13 07:07:58,180 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-13 07:07:58,214 - text_topic_extraction.cache.cache_manager - INFO - Stored response in cache with key ea74eadeb4...
# 2025-03-13 07:07:58,215 - text_topic_extraction.text_topic_processor - INFO - Generated 100 questions
# 2025-03-13 07:07:58,215 - text_topic_extraction.text_topic_processor - INFO - Question for topic 100: Is the patient retired or semiretired?
# 2025-03-13 07:07:58,216 - text_topic_extraction.text_topic_processor - INFO - Question for topic 101: Does the patient receive support from welfare or social services?
# 2025-03-13 07:07:58,216 - text_topic_extraction.text_topic_processor - INFO - Question for topic 102: Does the patient have any neurological conditions such as sclerosis or Parkinson's?
# 2025-03-13 07:07:58,216 - text_topic_extraction.text_topic_processor - INFO - Question for topic 103: Is the patient currently afebrile?
# 2025-03-13 07:07:58,217 - text_topic_extraction.text_topic_processor - INFO - Question for topic 104: Are there any children or kids involved in the patient's care?
# 2025-03-13 07:07:58,217 - text_topic_extraction.text_topic_processor - INFO - Question for topic 105: Is there an update on the patient's condition?
# 2025-03-13 07:07:58,218 - text_topic_extraction.text_topic_processor - INFO - Question for topic 106: Has the patient undergone cardiac catheterization?
# 2025-03-13 07:07:58,218 - text_topic_extraction.text_topic_processor - INFO - Question for topic 107: Does the patient have healthcare insurance or are they uninsured?
# 2025-03-13 07:07:58,218 - text_topic_extraction.text_topic_processor - INFO - Question for topic 108: Was the patient admitted to the hospital?
# 2025-03-13 07:07:58,219 - text_topic_extraction.text_topic_processor - INFO - Question for topic 109: Is there any indication of substance misuse in the patient's history?
# 2025-03-13 07:07:58,219 - text_topic_extraction.text_topic_processor - INFO - Question for topic 110: Has the patient had a recent dental checkup?
# 2025-03-13 07:07:58,219 - text_topic_extraction.text_topic_processor - INFO - Question for topic 111: Has the patient undergone a medical evaluation?
# 2025-03-13 07:07:58,220 - text_topic_extraction.text_topic_processor - INFO - Question for topic 112: Is the patient currently asymptomatic?
# 2025-03-13 07:07:58,220 - text_topic_extraction.text_topic_processor - INFO - Question for topic 113: Is the patient's smoking history unclear?
# 2025-03-13 07:07:58,220 - text_topic_extraction.text_topic_processor - INFO - Question for topic 114: Has the patient experienced any hemorrhage or hemorrhoids?
# 2025-03-13 07:07:58,221 - text_topic_extraction.text_topic_processor - INFO - Question for topic 115: Is the patient experiencing confusion?
# 2025-03-13 07:07:58,221 - text_topic_extraction.text_topic_processor - INFO - Question for topic 116: Is the patient on broad-spectrum antibiotics?
# 2025-03-13 07:07:58,221 - text_topic_extraction.text_topic_processor - INFO - Question for topic 117: Are socioeconomic determinants contributing to the patient's condition?
# 2025-03-13 07:07:58,221 - text_topic_extraction.text_topic_processor - INFO - Question for topic 118: Is the patient experiencing flu-like symptoms?
# 2025-03-13 07:07:58,221 - text_topic_extraction.text_topic_processor - INFO - Question for topic 119: Is the patient experiencing tenderness in the buttock area?
# 2025-03-13 07:07:58,222 - text_topic_extraction.text_topic_processor - INFO - Question for topic 120: Is the patient's blood pressure unmanaged?
# 2025-03-13 07:07:58,222 - text_topic_extraction.text_topic_processor - INFO - Question for topic 121: Does the patient drink alcohol only occasionally or rarely?
# 2025-03-13 07:07:58,222 - text_topic_extraction.text_topic_processor - INFO - Question for topic 122: Is the patient experiencing stomach ache or soreness?
# 2025-03-13 07:07:58,222 - text_topic_extraction.text_topic_processor - INFO - Question for topic 123: Does the patient have cardiomyopathy?
# 2025-03-13 07:07:58,222 - text_topic_extraction.text_topic_processor - INFO - Question for topic 124: Does the patient have a romantic partner who is ill?
# 2025-03-13 07:07:58,223 - text_topic_extraction.text_topic_processor - INFO - Question for topic 125: Has the patient's preexisting condition improved?
# 2025-03-13 07:07:58,223 - text_topic_extraction.text_topic_processor - INFO - Question for topic 126: Does the patient have a lung infection or pharyngitis?
# 2025-03-13 07:07:58,223 - text_topic_extraction.text_topic_processor - INFO - Question for topic 127: Does the patient have any chronic conditions?
# 2025-03-13 07:07:58,223 - text_topic_extraction.text_topic_processor - INFO - Question for topic 128: Is the patient tobacco-free?
# 2025-03-13 07:07:58,224 - text_topic_extraction.text_topic_processor - INFO - Question for topic 129: Is the patient using any contraceptives?
# 2025-03-13 07:07:58,224 - text_topic_extraction.text_topic_processor - INFO - Question for topic 130: Is the patient receiving critical care?
# 2025-03-13 07:07:58,224 - text_topic_extraction.text_topic_processor - INFO - Question for topic 131: Does the patient consume vodka or other spirits?
# 2025-03-13 07:07:58,224 - text_topic_extraction.text_topic_processor - INFO - Question for topic 132: Is the patient experiencing dizziness?
# 2025-03-13 07:07:58,224 - text_topic_extraction.text_topic_processor - INFO - Question for topic 133: Is the patient suspected to have hypertension (HTN)?
# 2025-03-13 07:07:58,225 - text_topic_extraction.text_topic_processor - INFO - Question for topic 134: Has the patient's examination results been normalized?
# 2025-03-13 07:07:58,225 - text_topic_extraction.text_topic_processor - INFO - Question for topic 135: Has the patient been hospitalized recently?
# 2025-03-13 07:07:58,225 - text_topic_extraction.text_topic_processor - INFO - Question for topic 136: Is the patient experiencing hemiparesis or hemoptysis?
# 2025-03-13 07:07:58,225 - text_topic_extraction.text_topic_processor - INFO - Question for topic 137: Is the patient's oral intake poor?
# 2025-03-13 07:07:58,225 - text_topic_extraction.text_topic_processor - INFO - Question for topic 138: Does the patient reside in a specific residence?
# 2025-03-13 07:07:58,226 - text_topic_extraction.text_topic_processor - INFO - Question for topic 139: Is the patient around 50 years old?
# 2025-03-13 07:07:58,226 - text_topic_extraction.text_topic_processor - INFO - Question for topic 140: Is the patient a nondrinker or ex-drinker?
# 2025-03-13 07:07:58,226 - text_topic_extraction.text_topic_processor - INFO - Question for topic 141: Is the patient a young adult?
# 2025-03-13 07:07:58,226 - text_topic_extraction.text_topic_processor - INFO - Question for topic 142: Does the patient drink alcohol rarely?
# 2025-03-13 07:07:58,226 - text_topic_extraction.text_topic_processor - INFO - Question for topic 143: Is the patient experiencing loose stools?
# 2025-03-13 07:07:58,227 - text_topic_extraction.text_topic_processor - INFO - Question for topic 144: Is there any mention of SDOH in the patient's notes?
# 2025-03-13 07:07:58,227 - text_topic_extraction.text_topic_processor - INFO - Question for topic 145: Is the patient in a correctional facility?
# 2025-03-13 07:07:58,227 - text_topic_extraction.text_topic_processor - INFO - Question for topic 146: Is the patient on heparin or warfarin?
# 2025-03-13 07:07:58,227 - text_topic_extraction.text_topic_processor - INFO - Question for topic 147: Has the patient undergone catheterization?
# 2025-03-13 07:07:58,227 - text_topic_extraction.text_topic_processor - INFO - Question for topic 148: Is the patient seeing a healthcare provider?
# 2025-03-13 07:07:58,228 - text_topic_extraction.text_topic_processor - INFO - Question for topic 149: Is there a caregiver involved in the patient's care?
# 2025-03-13 07:07:58,228 - text_topic_extraction.text_topic_processor - INFO - Question for topic 150: Does the patient have any arrhythmias?
# 2025-03-13 07:07:58,228 - text_topic_extraction.text_topic_processor - INFO - Question for topic 151: Is the patient currently working?
# 2025-03-13 07:07:58,228 - text_topic_extraction.text_topic_processor - INFO - Question for topic 152: Has the patient undergone a bedside assessment?
# 2025-03-13 07:07:58,229 - text_topic_extraction.text_topic_processor - INFO - Question for topic 153: Is there demographic information available for the patient?
# 2025-03-13 07:07:58,229 - text_topic_extraction.text_topic_processor - INFO - Question for topic 154: Does the patient have liver disease?
# 2025-03-13 07:07:58,229 - text_topic_extraction.text_topic_processor - INFO - Question for topic 155: Is the patient experiencing tiredness?
# 2025-03-13 07:07:58,229 - text_topic_extraction.text_topic_processor - INFO - Question for topic 156: Does the patient have any wounds or stabs?
# 2025-03-13 07:07:58,230 - text_topic_extraction.text_topic_processor - INFO - Question for topic 157: Does the patient smoke cigarettes?
# 2025-03-13 07:07:58,230 - text_topic_extraction.text_topic_processor - INFO - Question for topic 158: Does the patient have congestive heart failure?
# 2025-03-13 07:07:58,230 - text_topic_extraction.text_topic_processor - INFO - Question for topic 159: Is the patient's airway being managed?
# 2025-03-13 07:07:58,230 - text_topic_extraction.text_topic_processor - INFO - Question for topic 160: Is the patient able to walk?
# 2025-03-13 07:07:58,231 - text_topic_extraction.text_topic_processor - INFO - Question for topic 161: Is the patient undergoing rehabilitation?
# 2025-03-13 07:07:58,231 - text_topic_extraction.text_topic_processor - INFO - Question for topic 162: Has the patient had a stent placed?
# 2025-03-13 07:07:58,231 - text_topic_extraction.text_topic_processor - INFO - Question for topic 163: Is there any mention of ED in the patient's notes?
# 2025-03-13 07:07:58,231 - text_topic_extraction.text_topic_processor - INFO - Question for topic 164: Has the patient been transferred by helicopter?
# 2025-03-13 07:07:58,231 - text_topic_extraction.text_topic_processor - INFO - Question for topic 165: Is the patient experiencing excessive sweating?
# 2025-03-13 07:07:58,231 - text_topic_extraction.text_topic_processor - INFO - Question for topic 166: Has the patient been relocated recently?
# 2025-03-13 07:07:58,232 - text_topic_extraction.text_topic_processor - INFO - Question for topic 167: Is there a child or infant involved in the patient's care?
# 2025-03-13 07:07:58,232 - text_topic_extraction.text_topic_processor - INFO - Question for topic 168: Does the patient live alone?
# 2025-03-13 07:07:58,232 - text_topic_extraction.text_topic_processor - INFO - Question for topic 169: Is the patient experiencing hypoxia?
# 2025-03-13 07:07:58,232 - text_topic_extraction.text_topic_processor - INFO - Question for topic 170: Is the patient experiencing weight loss?
# 2025-03-13 07:07:58,232 - text_topic_extraction.text_topic_processor - INFO - Question for topic 171: Is the patient independent?
# 2025-03-13 07:07:58,233 - text_topic_extraction.text_topic_processor - INFO - Question for topic 172: Has the patient been intubated?
# 2025-03-13 07:07:58,233 - text_topic_extraction.text_topic_processor - INFO - Question for topic 173: Is the patient unemployed?
# 2025-03-13 07:07:58,233 - text_topic_extraction.text_topic_processor - INFO - Question for topic 174: Is there any mention of troponin levels in the patient's notes?
# 2025-03-13 07:07:58,233 - text_topic_extraction.text_topic_processor - INFO - Question for topic 175: Is the patient undergoing detox for heroin?
# 2025-03-13 07:07:58,234 - text_topic_extraction.text_topic_processor - INFO - Question for topic 176: Is the patient experiencing painful urination?
# 2025-03-13 07:07:58,234 - text_topic_extraction.text_topic_processor - INFO - Question for topic 177: Has the patient experienced a fall recently?
# 2025-03-13 07:07:58,234 - text_topic_extraction.text_topic_processor - INFO - Question for topic 178: Has the patient undergone an elective procedure?
# 2025-03-13 07:07:58,234 - text_topic_extraction.text_topic_processor - INFO - Question for topic 179: Is the patient living in a group home?
# 2025-03-13 07:07:58,235 - text_topic_extraction.text_topic_processor - INFO - Question for topic 180: Is the patient receiving inpatient care?
# 2025-03-13 07:07:58,235 - text_topic_extraction.text_topic_processor - INFO - Question for topic 181: Are there any risk factors mentioned in the patient's notes?
# 2025-03-13 07:07:58,235 - text_topic_extraction.text_topic_processor - INFO - Question for topic 182: Is there background information available for the patient?
# 2025-03-13 07:07:58,235 - text_topic_extraction.text_topic_processor - INFO - Question for topic 183: Has the patient undergone CABG surgery?
# 2025-03-13 07:07:58,236 - text_topic_extraction.text_topic_processor - INFO - Question for topic 184: Is the patient experiencing lightheadedness?
# 2025-03-13 07:07:58,236 - text_topic_extraction.text_topic_processor - INFO - Question for topic 185: Is the patient's blood pressure reading 70/30 or 80/40?
# 2025-03-13 07:07:58,236 - text_topic_extraction.text_topic_processor - INFO - Question for topic 186: Is the patient experiencing oxygen deprivation?
# 2025-03-13 07:07:58,237 - text_topic_extraction.text_topic_processor - INFO - Question for topic 187: Is the patient a heavy smoker?
# 2025-03-13 07:07:58,237 - text_topic_extraction.text_topic_processor - INFO - Question for topic 188: Is the patient employed part-time?
# 2025-03-13 07:07:58,237 - text_topic_extraction.text_topic_processor - INFO - Question for topic 189: Does the patient have pancreatitis?
# 2025-03-13 07:07:58,237 - text_topic_extraction.text_topic_processor - INFO - Question for topic 190: Has the patient had a chest x-ray?
# 2025-03-13 07:07:58,238 - text_topic_extraction.text_topic_processor - INFO - Question for topic 191: Is the duration of the patient's symptoms short?
# 2025-03-13 07:07:58,238 - text_topic_extraction.text_topic_processor - INFO - Question for topic 192: Does the patient have an extensive history of smoking?
# 2025-03-13 07:07:58,238 - text_topic_extraction.text_topic_processor - INFO - Question for topic 193: Is the patient experiencing shortness of breath?
# 2025-03-13 07:07:58,238 - text_topic_extraction.text_topic_processor - INFO - Question for topic 194: Is transportation an issue for the patient?
# 2025-03-13 07:07:58,238 - text_topic_extraction.text_topic_processor - INFO - Question for topic 195: Is the patient experiencing breathlessness at nighttime?
# 2025-03-13 07:07:58,238 - text_topic_extraction.text_topic_processor - INFO - Question for topic 196: Is the patient's condition progressing?
# 2025-03-13 07:07:58,239 - text_topic_extraction.text_topic_processor - INFO - Question for topic 197: Is there a lesion present in the patient's notes?
# 2025-03-13 07:07:58,239 - text_topic_extraction.text_topic_processor - INFO - Question for topic 198: Is the patient experiencing respiratory compromise?
# 2025-03-13 07:07:58,239 - text_topic_extraction.text_topic_processor - INFO - Question for topic 199: Is the patient experiencing vision problems or blindness?
# 2025-03-13 07:07:58,240 - text_topic_extraction.text_topic_processor - INFO - Generating questions for 100 topics
# topic question ex: topic_id=100 topic_name='retired semiretired ' question='Is the patient retired or semiretired?' keywords=['retired', 'semiretired', '', '', '', '', '', '', '', ''] keyword_scores=[0.44407066909305615, 0.0979544590171156, 1e-05, 1e-05, 1e-05, 1e-05, 1e-05, 1e-05, 1e-05, 1e-05]
# num topics 100
# 2025-03-13 07:08:31,995 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-13 07:08:32,024 - text_topic_extraction.cache.cache_manager - INFO - Stored response in cache with key 014ba907c1...
# 2025-03-13 07:08:32,025 - text_topic_extraction.text_topic_processor - INFO - Generated 100 questions
# 2025-03-13 07:08:32,025 - text_topic_extraction.text_topic_processor - INFO - Question for topic 200: Is there a mention of a blockage or blocked artery?
# 2025-03-13 07:08:32,026 - text_topic_extraction.text_topic_processor - INFO - Question for topic 201: Is the location of interest near a door or in North Carolina?
# 2025-03-13 07:08:32,026 - text_topic_extraction.text_topic_processor - INFO - Question for topic 202: Is there a condition affecting the heart or cardiac function?
# 2025-03-13 07:08:32,027 - text_topic_extraction.text_topic_processor - INFO - Question for topic 203: Does the CXR show any proximal findings?
# 2025-03-13 07:08:32,027 - text_topic_extraction.text_topic_processor - INFO - Question for topic 204: Is the patient underage, specifically 16 or younger?
# 2025-03-13 07:08:32,028 - text_topic_extraction.text_topic_processor - INFO - Question for topic 205: Is the patient unresponsive or showing signs of hyperreflexia?
# 2025-03-13 07:08:32,028 - text_topic_extraction.text_topic_processor - INFO - Question for topic 206: Is there a COPD flare or a specific stage mentioned?
# 2025-03-13 07:08:32,028 - text_topic_extraction.text_topic_processor - INFO - Question for topic 207: Is there an intervention or therapeutic attention required?
# 2025-03-13 07:08:32,029 - text_topic_extraction.text_topic_processor - INFO - Question for topic 208: Is there a mention of CRI, CR, or URI?
# 2025-03-13 07:08:32,029 - text_topic_extraction.text_topic_processor - INFO - Question for topic 209: Is there an ulcer or peptic ulcer mentioned?
# 2025-03-13 07:08:32,029 - text_topic_extraction.text_topic_processor - INFO - Question for topic 210: Are there any laboratory or lab results discussed?
# 2025-03-13 07:08:32,029 - text_topic_extraction.text_topic_processor - INFO - Question for topic 211: Is there a mention of HCT, HCP, or HEPC?
# 2025-03-13 07:08:32,030 - text_topic_extraction.text_topic_processor - INFO - Question for topic 212: Is the patient taking aspirin or somatostatin daily?
# 2025-03-13 07:08:32,030 - text_topic_extraction.text_topic_processor - INFO - Question for topic 213: Is there a mention of a parent or childless status?
# 2025-03-13 07:08:32,030 - text_topic_extraction.text_topic_processor - INFO - Question for topic 214: Is there a mention of illicit or illegal substances?
# 2025-03-13 07:08:32,030 - text_topic_extraction.text_topic_processor - INFO - Question for topic 215: Is the patient maintaining sobriety or a sober lifestyle?
# 2025-03-13 07:08:32,031 - text_topic_extraction.text_topic_processor - INFO - Question for topic 216: Is there a mention of esophageal issues or esophagitis?
# 2025-03-13 07:08:32,031 - text_topic_extraction.text_topic_processor - INFO - Question for topic 217: Is there a need for pain control or management?
# 2025-03-13 07:08:32,031 - text_topic_extraction.text_topic_processor - INFO - Question for topic 218: Was the patient transferred or transported by helicopter?
# 2025-03-13 07:08:32,031 - text_topic_extraction.text_topic_processor - INFO - Question for topic 219: Is there a head CT scan mentioned?
# 2025-03-13 07:08:32,031 - text_topic_extraction.text_topic_processor - INFO - Question for topic 220: Is there a mention of EMS or EMT involvement?
# 2025-03-13 07:08:32,032 - text_topic_extraction.text_topic_processor - INFO - Question for topic 221: Is there a mention of long-term or short-term care?
# 2025-03-13 07:08:32,032 - text_topic_extraction.text_topic_processor - INFO - Question for topic 222: Has the patient moved or relocated recently?
# 2025-03-13 07:08:32,032 - text_topic_extraction.text_topic_processor - INFO - Question for topic 223: Is there an altered mental status noted?
# 2025-03-13 07:08:32,032 - text_topic_extraction.text_topic_processor - INFO - Question for topic 224: Is there an absence of chest pain?
# 2025-03-13 07:08:32,032 - text_topic_extraction.text_topic_processor - INFO - Question for topic 225: Is there a mention of both sides or a specific side?
# 2025-03-13 07:08:32,033 - text_topic_extraction.text_topic_processor - INFO - Question for topic 226: Is there a change in mental status or retardation?
# 2025-03-13 07:08:32,033 - text_topic_extraction.text_topic_processor - INFO - Question for topic 227: Is there inflammation or cellulitis present?
# 2025-03-13 07:08:32,033 - text_topic_extraction.text_topic_processor - INFO - Question for topic 228: Is there a collection of pink fluid noted?
# 2025-03-13 07:08:32,033 - text_topic_extraction.text_topic_processor - INFO - Question for topic 229: Is there a mention of DM or DM2?
# 2025-03-13 07:08:32,033 - text_topic_extraction.text_topic_processor - INFO - Question for topic 230: Is there a mass or solid non-throbbing structure noted?
# 2025-03-13 07:08:32,034 - text_topic_extraction.text_topic_processor - INFO - Question for topic 231: Is there a mention of a single status or condition?
# 2025-03-13 07:08:32,034 - text_topic_extraction.text_topic_processor - INFO - Question for topic 232: Is respiratory support or assistance required?
# 2025-03-13 07:08:32,034 - text_topic_extraction.text_topic_processor - INFO - Question for topic 233: Is the patient living a drug-free or pet-free lifestyle?
# 2025-03-13 07:08:32,035 - text_topic_extraction.text_topic_processor - INFO - Question for topic 234: Is there a mention of neurology or natriuretic peptides?
# 2025-03-13 07:08:32,035 - text_topic_extraction.text_topic_processor - INFO - Question for topic 235: Is there a long-term illness being traced?
# 2025-03-13 07:08:32,035 - text_topic_extraction.text_topic_processor - INFO - Question for topic 236: Is insulin being administered via drip?
# 2025-03-13 07:08:32,036 - text_topic_extraction.text_topic_processor - INFO - Question for topic 237: Is the aorta dilated or is there an ascending aorta issue?
# 2025-03-13 07:08:32,036 - text_topic_extraction.text_topic_processor - INFO - Question for topic 238: Is there a mention of substance abuse or non-abuse?
# 2025-03-13 07:08:32,037 - text_topic_extraction.text_topic_processor - INFO - Question for topic 239: Is there a cerebrovascular accident or cerebrospinal issue?
# 2025-03-13 07:08:32,037 - text_topic_extraction.text_topic_processor - INFO - Question for topic 240: Is there a mention of drug use or boxing?
# 2025-03-13 07:08:32,037 - text_topic_extraction.text_topic_processor - INFO - Question for topic 241: Is there ongoing monitoring or surveillance required?
# 2025-03-13 07:08:32,038 - text_topic_extraction.text_topic_processor - INFO - Question for topic 242: Is there bleeding or a parenchymal issue noted?
# 2025-03-13 07:08:32,038 - text_topic_extraction.text_topic_processor - INFO - Question for topic 243: Is there a mention of diabetes mellitus or ketoacidosis?
# 2025-03-13 07:08:32,038 - text_topic_extraction.text_topic_processor - INFO - Question for topic 244: Is there a mention of hazardous substances or asbestos?
# 2025-03-13 07:08:32,038 - text_topic_extraction.text_topic_processor - INFO - Question for topic 245: Is there an aneurysm or acomm aneurysm mentioned?
# 2025-03-13 07:08:32,039 - text_topic_extraction.text_topic_processor - INFO - Question for topic 246: Is there a graft or saphenous vein graft mentioned?
# 2025-03-13 07:08:32,039 - text_topic_extraction.text_topic_processor - INFO - Question for topic 247: Is there a urinary tract infection noted?
# 2025-03-13 07:08:32,039 - text_topic_extraction.text_topic_processor - INFO - Question for topic 248: Is there a mention of a tube, PEG, or endotracheal tube?
# 2025-03-13 07:08:32,039 - text_topic_extraction.text_topic_processor - INFO - Question for topic 249: Is there a mention of AFib with RVR?
# 2025-03-13 07:08:32,039 - text_topic_extraction.text_topic_processor - INFO - Question for topic 250: Is there a mention of disability or intellectual disability?
# 2025-03-13 07:08:32,040 - text_topic_extraction.text_topic_processor - INFO - Question for topic 251: Is there a mention of gastric or gastrointestinal issues?
# 2025-03-13 07:08:32,040 - text_topic_extraction.text_topic_processor - INFO - Question for topic 252: Is there a mention of nephrolithiasis or kidney issues?
# 2025-03-13 07:08:32,040 - text_topic_extraction.text_topic_processor - INFO - Question for topic 253: Are the findings within normal limits or state?
# 2025-03-13 07:08:32,040 - text_topic_extraction.text_topic_processor - INFO - Question for topic 254: Is there an echocardiogram or transesophageal echocardiogram mentioned?
# 2025-03-13 07:08:32,040 - text_topic_extraction.text_topic_processor - INFO - Question for topic 255: Is there a mention of household chores or tax issues?
# 2025-03-13 07:08:32,041 - text_topic_extraction.text_topic_processor - INFO - Question for topic 256: Does the patient live with family or stay at home?
# 2025-03-13 07:08:32,041 - text_topic_extraction.text_topic_processor - INFO - Question for topic 257: Is there a mention of a relationship or girlfriend?
# 2025-03-13 07:08:32,041 - text_topic_extraction.text_topic_processor - INFO - Question for topic 258: Is there a mention of a daughter or granddaughter?
# 2025-03-13 07:08:32,041 - text_topic_extraction.text_topic_processor - INFO - Question for topic 259: Is there a mention of LVEF or RCA?
# 2025-03-13 07:08:32,041 - text_topic_extraction.text_topic_processor - INFO - Question for topic 260: Is there a mention of a sister or sibling?
# 2025-03-13 07:08:32,041 - text_topic_extraction.text_topic_processor - INFO - Question for topic 261: Is the patient living independently?
# 2025-03-13 07:08:32,042 - text_topic_extraction.text_topic_processor - INFO - Question for topic 262: Is there a mention of urine output or culture?
# 2025-03-13 07:08:32,042 - text_topic_extraction.text_topic_processor - INFO - Question for topic 263: Is there a mention of solitary or solo living?
# 2025-03-13 07:08:32,042 - text_topic_extraction.text_topic_processor - INFO - Question for topic 264: Is there a mention of psychosis or schizoaffective disorder?
# 2025-03-13 07:08:32,042 - text_topic_extraction.text_topic_processor - INFO - Question for topic 265: Is there a mention of a gentleman?
# 2025-03-13 07:08:32,043 - text_topic_extraction.text_topic_processor - INFO - Question for topic 266: Is there a mention of a valve or prosthetic anomaly?
# 2025-03-13 07:08:32,043 - text_topic_extraction.text_topic_processor - INFO - Question for topic 267: Is there a mention of hypercholesterolemia or high cholesterol?
# 2025-03-13 07:08:32,043 - text_topic_extraction.text_topic_processor - INFO - Question for topic 268: Is mechanical ventilation or noninvasive ventilation required?
# 2025-03-13 07:08:32,043 - text_topic_extraction.text_topic_processor - INFO - Question for topic 269: Is there a mention of perfusion or MRI imaging?
# 2025-03-13 07:08:32,044 - text_topic_extraction.text_topic_processor - INFO - Question for topic 270: Is there a mention of temperature or cooling?
# 2025-03-13 07:08:32,044 - text_topic_extraction.text_topic_processor - INFO - Question for topic 271: Is there a mention of fainting or faintness?
# 2025-03-13 07:08:32,044 - text_topic_extraction.text_topic_processor - INFO - Question for topic 272: Is there a mention of dialysis or hemodialysis?
# 2025-03-13 07:08:32,044 - text_topic_extraction.text_topic_processor - INFO - Question for topic 273: Is there a mention of travel or a trip?
# 2025-03-13 07:08:32,045 - text_topic_extraction.text_topic_processor - INFO - Question for topic 274: Is there a mention of rehab or a rehab session?
# 2025-03-13 07:08:32,045 - text_topic_extraction.text_topic_processor - INFO - Question for topic 275: Is the patient incarcerated or on probation?
# 2025-03-13 07:08:32,045 - text_topic_extraction.text_topic_processor - INFO - Question for topic 276: Is there a mention of nonreconstructable or occlusive disease?
# 2025-03-13 07:08:32,045 - text_topic_extraction.text_topic_processor - INFO - Question for topic 277: Is there a mention of respiratory failure or hypercarbia?
# 2025-03-13 07:08:32,046 - text_topic_extraction.text_topic_processor - INFO - Question for topic 278: Is there a mention of injuries or an injury case?
# 2025-03-13 07:08:32,046 - text_topic_extraction.text_topic_processor - INFO - Question for topic 279: Is there a mention of bypass grafting or a graft?
# 2025-03-13 07:08:32,046 - text_topic_extraction.text_topic_processor - INFO - Question for topic 280: Is there a mention of pantoprazole or lorazepam?
# 2025-03-13 07:08:32,046 - text_topic_extraction.text_topic_processor - INFO - Question for topic 281: Is there a mention of resuscitation or cardiopulmonary resuscitation?
# 2025-03-13 07:08:32,047 - text_topic_extraction.text_topic_processor - INFO - Question for topic 282: Is there a mention of therapy or psychotherapy?
# 2025-03-13 07:08:32,047 - text_topic_extraction.text_topic_processor - INFO - Question for topic 283: Is there a mention of postoperative or preoperative status?
# 2025-03-13 07:08:32,047 - text_topic_extraction.text_topic_processor - INFO - Question for topic 284: Is there a mention of mitral valve or endocarditis?
# 2025-03-13 07:08:32,047 - text_topic_extraction.text_topic_processor - INFO - Question for topic 285: Is there a mention of an external facility or referral?
# 2025-03-13 07:08:32,048 - text_topic_extraction.text_topic_processor - INFO - Question for topic 286: Is there a mention of steroid use or cream?
# 2025-03-13 07:08:32,048 - text_topic_extraction.text_topic_processor - INFO - Question for topic 287: Is there a mention of myocardial infarction?
# 2025-03-13 07:08:32,048 - text_topic_extraction.text_topic_processor - INFO - Question for topic 288: Is there a mention of patient oversight or history?
# 2025-03-13 07:08:32,048 - text_topic_extraction.text_topic_processor - INFO - Question for topic 289: Is there a mention of an abstainer?
# 2025-03-13 07:08:32,048 - text_topic_extraction.text_topic_processor - INFO - Question for topic 290: Is there a mention of intensive care or surgical treatment?
- text_topic_extraction.text_topic_processor - INFO - Question for topic 1299: Is there a mention of homelessness?
# 2025-03-13 07:14:35,833 - text_topic_extraction.text_topic_processor - INFO - Generating questions for 19 topics
# topic question ex: topic_id=1200 topic_name='81f 60f 52f' question='Is the patient a female in her 80s, 60s, or 50s?' keywords=['81f', '60f', '52f', '40s50s', '25f', '41', '', '', '', ''] keyword_scores=[0.8177716802655624, 0.5037657892308802, 0.5037657892308802, 0.5037657892308802, 0.5037657892308802, 0.35498666425542863, 1e-05, 1e-05, 1e-05, 1e-05]
# num topics 100
# 2025-03-13 07:14:49,080 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-13 07:14:49,108 - text_topic_extraction.cache.cache_manager - INFO - Stored response in cache with key c4edb2d511...
# 2025-03-13 07:14:49,110 - text_topic_extraction.text_topic_processor - INFO - Generated 19 questions
# 2025-03-13 07:14:49,110 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1300: Is the patient receiving nonhospital medical treatment?
# 2025-03-13 07:14:49,110 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1301: Was a tissue sample taken for analysis?
# 2025-03-13 07:14:49,110 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1302: Is the severity of the condition considered medium or average?
# 2025-03-13 07:14:49,111 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1303: Is there any mention of obstructed airways or obtundation?
# 2025-03-13 07:14:49,111 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1304: Is there evidence of separation or stranding in the medical imaging?
# 2025-03-13 07:14:49,111 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1305: Is the patient at risk of falling?
# 2025-03-13 07:14:49,111 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1306: Is the patient 64 years old?
# 2025-03-13 07:14:49,111 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1307: Is the patient experiencing hypoxemia?
# 2025-03-13 07:14:49,112 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1308: Does the patient require home aide assistance?
# 2025-03-13 07:14:49,112 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1309: Is the patient experiencing clamminess or clumsiness?
# 2025-03-13 07:14:49,112 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1310: Has the patient refused treatment or medication?
# 2025-03-13 07:14:49,112 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1311: Is there intraperitoneal bleeding noted?
# 2025-03-13 07:14:49,113 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1312: Is there an issue with arterial or vascular access?
# 2025-03-13 07:14:49,113 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1313: Is the patient 56 years old?
# 2025-03-13 07:14:49,113 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1314: Is there a mention of a left-sided or symmetric condition?
# 2025-03-13 07:14:49,113 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1315: Are the symptoms unchanged from the preceding assessment?
# 2025-03-13 07:14:49,113 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1316: Has a comprehensive assessment been performed?
# 2025-03-13 07:14:49,114 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1317: Are there any geriatric concerns noted in the care plan?
# 2025-03-13 07:14:49,114 - text_topic_extraction.text_topic_processor - INFO - Question for topic 1318: Is the patient a nonsmoker?
# topic question ex: topic_id=1300 topic_name='nonhospital treatment medical' question='Is the patient receiving nonhospital medical treatment?' keywords=['nonhospital', 'treatment', 'medical', '', '', '', '', '', '', ''] keyword_scores=[0.2385167400774557, 0.07497007364545744, 0.03210455534029746, 1e-05, 1e-05, 1e-05, 1e-05, 1e-05, 1e-05, 1e-05]
# num topics 19

# %%
patient_id = str(train_idxs[0])
topic_answers = answer_generator.generate_answers(
    patient_concepts=patient_concepts[patient_id],
    topic_questions=all_topic_questions,
    patient_notes=patient_notes[patient_id],
)
# Out:
# 2025-03-13 07:34:03,469 - text_topic_extraction.answer_generator.answer_generator - INFO - Generating answers for patient 2200 for 1319 questions
# 2025-03-13 07:34:03,470 - text_topic_extraction.answer_generator.answer_generator - INFO - Sending batch of 1319 questions for patient 2200
# 2025-03-13 07:34:03,485 - text_topic_extraction.llm_api.openai_client - INFO - Using cached structured response (key: 3ebf4b8fa8...)

# %%
topic_answers
# Out:
# [TopicAnswer(topic_id=0, topic_name='elderly aging person', question='Is the patient described as an elderly or aging person?', probability=0.0, answer=False),
#  TopicAnswer(topic_id
', probability=0.0, answer=False),
#  TopicAnswer(topic_id=976, topic_name='melanoma nonmelanotic cyanosis', question='Is there any mention of melanoma or non-melanotic lesions?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=977, topic_name='tests laboratory lab', question='Are there any laboratory tests mentioned?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=978, topic_name='family history ', question='Is there any mention of family history?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=979, topic_name='screening screenings mra', question='Is there any mention of screening tests or MRA?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=980, topic_name='alterations distress insurance', question='Is there any mention of distress or insurance issues?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=981, topic_name='procedure heart cardiac', question='Is there any mention of a cardiac procedure?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=982, topic_name='twaves twave waves', question='Is there any mention of T-wave inversions?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=983, topic_name='substancerelated disorders disorder', question='Is there any mention of substance-related disorders?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=984, topic_name='fever fevers absence', question='Is there any mention of fever or absence of fever?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=985, topic_name='threevessel triple 3vessel', question='Is there any mention of three-vessel disease?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=986, topic_name='movements bowel movement', question='Is there any mention of bowel movements?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=987, topic_name='bilevel endexpiratory positive', question='Is there any mention of bilevel positive airway pressure?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=988, topic_name='distress respiratory arrest', question='Is there any mention of respiratory distress or arrest?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=989, topic_name='mds answering service', question='Is there any mention of an answering service or MDS?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=990, topic_name='metabolic metabolism disturbance', question='Is there any mention of metabolic disturbances?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=991, topic_name='agitated irritability movements', question='Is the patient described as agitated or irritable?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=992, topic_name='filter ivc vena', question='Is there any mention of an IVC filter?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=993, topic_name='shift midline 5mm', question='Is there any mention of a midline shift?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=994, topic_name='osh osa ', question='Is there any mention of OSA or OSH?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=995, topic_name='radiation radiates beam', question='Is there any mention of radiation therapy?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=996, topic_name='oriented upright rigidity', question='Is the patient oriented and upright?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=997, topic_name='counts levels supply', question='Is there any mention of blood counts or levels?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=998, topic_name='physical examination exam', question='Is there any mention of a physical examination?', probability=0.0, answer=False),
#  TopicAnswer(topic_id=999, topic_name='vessel around ruptured', question='Is there any mention of a ruptured vessel?', probability=0.0, answer=False),
#  ...]

# %%
patient_concepts_subset = {str(idx): patient_concepts[str(idx)] for idx in train_idxs[:50]}
processor.patient_notes = {str(idx): patient_notes[str(idx)] for idx in train_idxs[:50]}

patient_answers = processor._generate_answers(
    patient_concepts=patient_concepts_subset,
    topic_questions=all_topic_questions,
    answer_generator=answer_generator,
)
# Out:
# 2025-03-13 07:50:24,451 - text_topic_extraction.text_topic_processor - INFO - Generating answers for 50 patients
# 2025-03-13 07:50:24,451 - text_topic_extraction.text_topic_processor - INFO - Generating answers for patient 2200
# 2025-03-13 07:50:24,452 - text_topic_extraction.answer_generator.answer_generator - INFO - Generating answers for patient 2200 for 1319 questions
# 2025-03-13 07:50:24,453 - text_topic_extraction.answer_generator.answer_generator - INFO - Sending batch of 1319 questions for patient 2200
# 2025-03-13 07:50:24,465 - text_topic_extraction.llm_api.openai_client - INFO - Using cached structured response (key: 3ebf4b8fa8...)
# 2025-03-13 07:50:24,470 - text_topic_extraction.text_topic_processor - INFO - Generating answers for patient 4627
# 2025-03-13 07:50:24,470 - text_topic_extraction.answer_generator.answer_generator - INFO - Generating answers for patient 4627 for 1319 questions
# 2025-03-13 07:50:24,471 - text_topic_extraction.answer_generator.answer_generator - INFO - Sending batch of 1319 questions for patient 4627
# 2025-03-13 07:51:36,945 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-13 07:51:36,965 - text_topic_extraction.cache.cache_manager - INFO - Stored response in cache with key 85262632cc...
# 2025-03-13 07:51:36,969 - text_topic_extraction.text_topic_processor - INFO - Generating answers for patient 3225
# 2025-03-13 07:51:36,969 - text_topic_extraction.answer_generator.answer_generator - INFO - Generating answers for patient 3225 for 1319 questions
# 2025-03-13 07:51:36,970 - text_topic_extraction.answer_generator.answer_generator - INFO - Sending batch of 1319 questions for patient 3225
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 4
#       1 patient_concepts_subset = {str(idx): patient_concepts[str(idx)] for idx in train_idxs[:50]}
#       2 processor.patient_notes = {str(idx): patient_notes[str(idx)] for idx in train_idxs[:50]}
# ----> 4 patient_answers = processor._generate_answers(
#       5     patient_concepts=patient_concepts_subset,
#       6     topic_questions=all_topic_questions,
#       7     answer_generator=answer_generator,
#       8 )
#
# File ~/Documents/Research/bc-llm/text_topic_extraction/text_topic_processor.py:436, in TextTopicProcessor._generate_answers(self, patient_concepts, topic_questions, answer_generator)
#     433     patient_notes = self.patient_notes[patient_id]
#     435 # Generate answers with the full notes
# --> 436 answers = answer_generator.generate_answers(
#     437     patient_concepts=concepts,
#     438     topic_questions=topic_questions,
#     439     patient_notes=patient_notes,
#     440 )
#     442 # Store the results
#     443 patient_answers[patient_id] = answers
#
# File ~/Documents/Research/bc-llm/text_topic_extraction/answer_generator/answer_generator.py:201, in AnswerGenerator.generate_answers(self, patient_concepts, topic_questions, patient_notes)
#     195 logger.info(
#     196     f"Sending batch of {len(topic_questions)} questions for patient {patient_id}"
#     197 )
#     199 try:
#     200     # Use structured generation to get a clean JSON response
# --> 201     response = self.llm_api.send_structured_prompt(
#     202         prompt=prompt,
#     203         response_model=AnswerGenerationResult,
#     204     )
#     206     # The response should directly be a dictionary of question indices to probabilities
#     207     answers_dict = response["answers"]
#
# File ~/Documents/Research/bc-llm/text_topic_extraction/llm_api/openai_client.py:197, in OpenAIClient.send_structured_prompt(self, prompt, response_model)
#     184 def send_structured_prompt(
#     185     self, prompt: str, response_model: Type[BaseModel]
#     186 ) -> Dict[str, Any]:
#     187     """
#     188     Send a prompt to the LLM and get a structured response.
#     189
#    (...)    195         The structured response as a dictionary
#     196     """
# --> 197     return self.generate_structured_response(
#     198         prompt=prompt,
#     199         response_model=response_model,
#     200         use_cache=self.use_cache,
#     201     )
#
# File ~/Documents/Research/bc-llm/text_topic_extraction/llm_api/openai_client.py:252, in OpenAIClient.generate_structured_response(self, prompt, response_model, system_message, use_cache)
#     250 logger.debug(f"Generating structured response with model {self.model}")
#     251 try:
# --> 252     response = self.client.beta.chat.completions.parse(
#     253         model=self.model,
#     254         messages=[
#     255             {"role": "system", "content": system_message},
#     256             {"role": "user", "content": prompt},
#     257         ],
#     258         temperature=self.temperature,
#     259         response_format=response_model,
#     260     )
#     262     result = response.choices[0].message.parsed
#     263     result_dict = result.model_dump()
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/openai/resources/beta/chat/completions.py:158, in Completions.parse(self, messages, model, audio, response_format, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, seed, service_tier, stop, store, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     151 def parser(raw_completion: ChatCompletion) -> ParsedChatCompletion[ResponseFormatT]:
#     152     return _parse_chat_completion(
#     153         response_format=response_format,
#     154         chat_completion=raw_completion,
#     155         input_tools=tools,
#     156     )
# --> 158 return self._post(
#     159     "/chat/completions",
#     160     body=maybe_transform(
#     161         {
#     162             "messages": messages,
#     163             "model": model,
#     164             "audio": audio,
#     165             "frequency_penalty": frequency_penalty,
#     166             "function_call": function_call,
#     167             "functions": functions,
#     168             "logit_bias": logit_bias,
#     169             "logprobs": logprobs,
#     170             "max_completion_tokens": max_completion_tokens,
#     171             "max_tokens": max_tokens,
#     172             "metadata": metadata,
#     173             "modalities": modalities,
#     174             "n": n,
#     175             "parallel_tool_calls": parallel_tool_calls,
#     176             "prediction": prediction,
#     177             "presence_penalty": presence_penalty,
#     178             "reasoning_effort": reasoning_effort,
#     179             "response_format": _type_to_response_format(response_format),
#     180             "seed": seed,
#     181             "service_tier": service_tier,
#     182             "stop": stop,
#     183             "store": store,
#     184             "stream": False,
#     185             "stream_options": stream_options,
#     186             "temperature": temperature,
#     187             "tool_choice": tool_choice,
#     188             "tools": tools,
#     189             "top_logprobs": top_logprobs,
#     190             "top_p": top_p,
#     191             "user": user,
#     192             "web_search_options": web_search_options,
#     193         },
#     194         completion_create_params.CompletionCreateParams,
#     195     ),
#     196     options=make_request_options(
#     197         extra_headers=extra_headers,
#     198         extra_query=extra_query,
#     199         extra_body=extra_body,
#     200         timeout=timeout,
#     201         post_parser=parser,
#     202     ),
#     203     # we turn the `ChatCompletion` instance into a `ParsedChatCompletion`
#     204     # in the `parser` function above
#     205     cast_to=cast(Type[ParsedChatCompletion[ResponseFormatT]], ChatCompletion),
#     206     stream=False,
#     207 )
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/openai/_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)   1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/openai/_base_client.py:919, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     916 else:
#     917     retries_taken = 0
# --> 919 return self._request(
#     920     cast_to=cast_to,
#     921     options=options,
#     922     stream=stream,
#     923     stream_cls=stream_cls,
#     924     retries_taken=retries_taken,
#     925 )
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/openai/_base_client.py:955, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     952 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     954 try:
# --> 955     response = self._client.send(
#     956         request,
#     957         stream=stream or self._should_stream_response_body(request=request),
#     958         **kwargs,
#     959     )
#     960 except httpx.TimeoutException as err:
#     961     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Documents/Research/bc-llm/venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
# Create topic matrix
processor.topic_matrix = answer_generator.create_topic_matrix(patient_answers)

# Create matrix DataFrames (always do this even if not saving)
processor.binary_matrix_df = MatrixBuilder.create_binary_matrix(topic_matrix)
processor.probability_matrix_df = MatrixBuilder.create_probability_matrix(
    topic_matrix
)

# Create return dictionary with DataFrames
results = {
    "binary_matrix_df": binary_matrix_df,
    "probability_matrix_df": probability_matrix_df,
    "topic_matrix": topic_matrix,
    "topics": topics,
    "topic_questions": topic_questions,
}
# Out:
# ''

# %%
processor._save_results(
    patient_concepts=patient_concepts,
    topics=topics,
    topic_questions=topic_questions,
    patient_answers=patient_answers,
    topic_matrix=topic_matrix,
    output_dir="exp_mimic/_output",
    save_intermediate=False,
)
